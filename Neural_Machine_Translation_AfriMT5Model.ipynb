# %% [markdown]
# # Neural Machine Translation using a Transformer Model
#
# Finetune [AfriMT5](https://huggingface.co/masakhane/afri-mt5-base) to translate English to Akuapem Twi, dataset available on [Zenodo-AfricanNLP](https://zenodo.org/records/4432117).

# %% [markdown]
# ### Install all required libraries

# %%
# Installs all necessary libraries
# !pip install torch
# !pip install nlgeval
# !pip install torchvision
# !pip install nltk
# !pip install datasets
# !pip install transformers
# !pip install evaluate
# !pip install sacrebleu
# !pip install --upgrade --no-cache-dir gdown
# !pip install transformers sentencepiece
# !pip install accelerate>=0.21.0
# !pip install transformers[torch]
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.3.0+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.3.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch) (12.5.40)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# ERROR: Could not find a version that satisfies the requirement nlgeval (from versions: none)
# ERROR: No matching distribution found for nlgeval
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.18.0+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision) (1.25.2)
# Requirement already satisfied: torch==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (2.3.0+cu121)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (9.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch==2.3.0->torchvision) (3.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.3.0->torchvision) (4.12.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch==2.3.0->torchvision) (1.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch==2.3.0->torchvision) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch==2.3.0->torchvision) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch==2.3.0->torchvision) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch==2.3.0->torchvision) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch==2.3.0->torchvision) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch==2.3.0->torchvision) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch==2.3.0->torchvision) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch==2.3.0->torchvision) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch==2.3.0->torchvision) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch==2.3.0->torchvision) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch==2.3.0->torchvision) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch==2.3.0->torchvision) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch==2.3.0->torchvision) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch==2.3.0->torchvision) (12.1.105)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.3.0->torchvision) (2.3.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.3.0->torchvision) (12.5.40)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch==2.3.0->torchvision) (2.1.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch==2.3.0->torchvision) (1.3.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.5.15)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.4)
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (2.19.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.14.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.25.2)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.0.3)
# Requirement already satisfied: requests>=2.32.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.4)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec[http]<=2024.3.1,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.5)
# Requirement already satisfied: huggingface-hub>=0.21.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.23.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.2->datasets) (4.12.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.1->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.1->datasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.1->datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.1->datasets) (2024.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.41.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.14.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.23.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.0->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.0->transformers) (4.12.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.2.2)
# Requirement already satisfied: evaluate in /usr/local/lib/python3.10/dist-packages (0.4.2)
# Requirement already satisfied: datasets>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (2.19.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from evaluate) (1.25.2)
# Requirement already satisfied: dill in /usr/local/lib/python3.10/dist-packages (from evaluate) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from evaluate) (2.0.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (2.32.3)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from evaluate) (4.66.4)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from evaluate) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from evaluate) (0.70.16)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (2023.6.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (0.23.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from evaluate) (24.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (3.14.0)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (0.6)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (3.9.5)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.7.0->evaluate) (4.12.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (2024.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2024.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (4.0.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.16.0)
# Requirement already satisfied: sacrebleu in /usr/local/lib/python3.10/dist-packages (2.4.2)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (2.8.2)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (2024.5.15)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (0.9.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (1.25.2)
# Requirement already satisfied: colorama in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (0.4.6)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (4.9.4)
# Requirement already satisfied: gdown in /usr/local/lib/python3.10/dist-packages (5.2.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown) (4.12.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown) (3.14.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.10/dist-packages (from gdown) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from gdown) (4.66.4)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2024.2.2)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (1.7.1)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.41.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (0.1.99)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.14.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.23.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.0->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.0->transformers) (4.12.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.2.2)
# Requirement already satisfied: transformers[torch] in /usr/local/lib/python3.10/dist-packages (4.41.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (3.14.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (0.23.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (2.32.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (4.66.4)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (2.3.0+cu121)
# Requirement already satisfied: accelerate>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (0.30.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.21.0->transformers[torch]) (5.9.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.0->transformers[torch]) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.0->transformers[torch]) (4.12.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (1.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (3.1.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (12.1.105)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (2.3.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->transformers[torch]) (12.5.40)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->transformers[torch]) (2.1.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->transformers[torch]) (1.3.0)

# %%
import torch
import gc
import os
import psutil
from transformers import TrainingArguments, Trainer

# Function to clear memory
def clear_memory():
    print("Clearing CUDA cache and running garbage collection...")
    torch.cuda.empty_cache()
    gc.collect()
    print("Memory cleared.")
# Function to check memory usage
def print_memory_usage():
    process = psutil.Process(os.getpid())
    print(f"Memory Usage: {process.memory_info().rss / 1024**2:.2f} MB")

# Clear memory before training
clear_memory()
print_memory_usage()
# Out:
# Clearing CUDA cache and running garbage collection...
# Memory cleared.
# Memory Usage: 1014.18 MB

# %% [markdown]
# ### Import Libraries

# %%
# Imports all necessary libraries
import re
import torch
import pandas as pd
import numpy as np
import evaluate

from transformers import pipeline
from torch.utils.data import Dataset, DataLoader
from transformers import DataCollatorForSeq2Seq
from transformers import AutoTokenizer, MarianTokenizer, MarianMTModel
from sklearn.model_selection import train_test_split
from transformers import Trainer, TrainingArguments, AdamW
from transformers import AutoModelForSeq2SeqLM, Seq2SeqTrainingArguments, Seq2SeqTrainer
from datasets import load_dataset, load_metric, Dataset, DatasetDict, load_metric

# %% [markdown]
# ## Download the dataset
# Loads the English-Akuapem Twi datasets (training and validation):

# %%
# Loads the training dataset
df = pd.read_csv("verified_data.csv")
df.head()
# Out:
#                                              English  \
# 0  What she lacks in charisma she makes up for wi...
# 1             There was nothing I could do about it.
# 2            Kwaku saw John and Abena holding hands.
# 3                            Can you stay till 2:30?
# 4                         You haven't got much time.
#
#                                          Akuapem Twi
# 0        Nea onni ho adwempa no de adwumaden na ɛba.
# 1                   Na biribiara nni hɛ a metumi ayɔ
# 2      Kwaku hui se  John ne Abena kurakura wɛn nsa.
# 3  So wubetumi atena ha akosi nnɛnmienu npaamu ad...
# 4                                         Wonni mmre

# %%
# Loads the test dataset
df_test = pd.read_csv("crowdsourced_testdata.csv")
df_test.head()
# Out:
#                           English Sentence            Twi Translation
# 0                   What is going on here?  Ɛdeɛn na  ɛrekɔso wɔ aha?
# 1                                  Wake up                       Sɔre
# 2              She comes here every Friday         Ɔba ha Fiada biara
# 3                         Learn to be wise                 Sua nyansa
# 4  I didn’t think you would loose your way   Mannwene da sɛ wo bɛyera

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# This section aimed to prepare the two datasets (training and testing) and transform both into clean, structured, and useful formats. The collected datasets were mostly clean, therefore, the pipeline did not require alot of cleaning. The datasets had no missing values in the training dataset, two missing values in the test dataset, and a few duplicate values in both sets of which one of the duplicate values was dropped.

# %% [markdown]
# #### Data Cleaning

# %%
# Checks for missing values in the training dataset
df.isnull().sum()
# Out:
# English        0
# Akuapem Twi    0
# dtype: int64

# %%
# Checks for missing values in the testing datset
df_test.isnull().sum()
# Out:
# English Sentence    0
# Twi Translation     2
# dtype: int64

# %%
# Drops the two rows with missing values in the test set
df_test = df_test.dropna()

# %%
# Checks for duplicate values in each column in the train set
train_duplicate_counts = df.apply(lambda x: x.duplicated().sum())
print("Total duplicate values in each column:")
print(train_duplicate_counts)
# Out:
# Total duplicate values in each column:
# English        281
# Akuapem Twi    656
# dtype: int64

# %%
# Checks for duplicate values in each column in the test set
test_duplicate_counts_test = df_test.apply(lambda x: x.duplicated().sum())
print("Total duplicate values in each column:")
print(test_duplicate_counts_test)
# Out:
# Total duplicate values in each column:
# English Sentence    34
# Twi Translation     33
# dtype: int64

# %%
# Drops duplicate rows in the train set
df_updated = df.drop_duplicates()

# %%
# Drops duplicate rows in the test set
df_test_updated = df_test.drop_duplicates()

# %%
# Gets the total number of data points before and after dropping duplicates from the train set
total_rows_before_dropping = len(df)
print("Total number of rows before dropping duplicates:", total_rows_before_dropping)
total_rows_after_dropping = len(df_updated)
print("Total number of rows after dropping duplicates:", total_rows_after_dropping)
# Out:
# Total number of rows before dropping duplicates: 25420
# Total number of rows after dropping duplicates: 25171

# %%
# Gets the total number of data points before and after dropping duplicates from the test set
total_rows_before_dropping = len(df_test)
print("Total number of rows before dropping duplicates:", total_rows_before_dropping)
total_rows_after_dropping = len(df_test_updated)
print("Total number of rows after dropping duplicates:", total_rows_after_dropping)
# Out:
# Total number of rows before dropping duplicates: 695
# Total number of rows after dropping duplicates: 682

# %% [markdown]
# ####Data Formatting and Train Dataset Split

# %%
# Converts the dataframe columns to python lists for train sets
English_phrases = df['English'].tolist()
Twi_translations = df['Akuapem Twi'].tolist()

# %% [markdown]
# The training dataset is split into two sets: train set (80%) and validation set (20%). The pipeline has a separate test dataset that was separately gathered to be utilized as an evaluation set, hence, no need to split the train dataset any further.

# %%
# Splits the dataset into training and validation sets
train_english, val_english, train_twi, val_twi = train_test_split(English_phrases, Twi_translations, test_size=0.2)

# %% [markdown]
# ####Tokenization

# %% [markdown]
# The pipeline then loads the ``AfriMT5`` tokenizer to process the English-Akuapem Twi language pairs:
#
# The tokenizer aims to convert text into a format that the model can process by splitting text into tokens (subwords or words), converts the tokens into numerical IDs and adds any necessary special tokens. This pipeline uses the AutoTokenizer pre-trained on 'masakhane/afrimt5_en_twi_news'.

# %%
# Loads and initializes the tokenizers
tokenizer = AutoTokenizer.from_pretrained("masakhane/afrimt5_en_twi_news")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(

# %%
# Defines source and target languages and the translation prefix
source_lang = "en"
target_lang = "twi"
prefix = "translate English to Twi: "

# %% [markdown]
# The preprocess_function below prepares the data (ensure that all input data is uniformly processed) for model training and evaluation by:
#
# * Adding a translation prefix to the source sentences;
# * Tokenizing both the source and target sentences with appropriate padding and truncation; and,
# * Returning the tokenized data in a format that the model can understand.
#
# The defined below function named preprocess_function takes three (3) parameters;
# * examples - A dictionary containing source and target language sentences;
# * tokenizer - A tokenizer object from Hugging Face Transformers library; and,
# * max_length - An optional parameter that sets the maximum length for the tokenized sequences with default set as 128.
#
# The main steps involve preparing input sentences by prefixing each source language sentence with a translation prefix, preparing target sentences by listing the corresponding target language sentences, and tokenizing both inputs and targets into a suitable format for the model. Finally, the tokenized inputs, including token IDs and attention masks, are returned for model training and evaluation.

# %%
# Defines the preprocessing function
def preprocess_function(examples, tokenizer, max_length=128):
    inputs = [prefix + ex for ex in examples[source_lang]]
    targets = [ex for ex in examples[target_lang]]
    model_inputs = tokenizer(inputs, text_target=targets, max_length=max_length, truncation=True, padding='max_length')
    return model_inputs

# %% [markdown]
# The used Dataset class in the below cell is from the dataset library provided by Hugging Face. This library is used to handle and preprocess datasets efficiently for machine learning tasks, particularly in the context of natural language processing (NLP).
#
# The from_dict method is a class method that creates a Dataset object from a dictionary. The keys of the dictionary are the column names, and the values are lists of data corresponding to those columns.
#
# Variables and Data:
# source_lang and target_lang are variables holding the string values representing the source and target language keys, respectively.
# train_english and train_twi are lists containing English phrases and their corresponding Twi translations for the training set.
# val_english and val_twi are lists containing English phrases and their corresponding Twi translations for the validation set.

# %%
# Creates datasets
train_dataset = Dataset.from_dict({source_lang: train_english, target_lang: train_twi})
val_dataset = Dataset.from_dict({source_lang: val_english, target_lang: val_twi})

# %% [markdown]
# The below step maps the preprocess_function over both the training and validation datasets, tokenizing the examples in batches. This prepares the datasets for input into a machine learning model by converting text data into a format that the model can understand (e.g., token IDs, attention masks

# %%
# Preprocess datasets
tokenized_train_dataset = train_dataset.map(lambda x: preprocess_function(x, tokenizer), batched=True)
tokenized_val_dataset = val_dataset.map(lambda x: preprocess_function(x, tokenizer), batched=True)
# Out:
# Map:   0%|          | 0/20336 [00:00<?, ? examples/s]
# Map:   0%|          | 0/5084 [00:00<?, ? examples/s]

# %% [markdown]
# The code below ensures that only relevant columns remain in the tokenized datasets by removing the source language and target language columns which helps streamline the datasets for better performance and avoids unnecessary warnings related to unused columns.

# %%
# Removes unused columns to avoid warnings
tokenized_train_dataset = tokenized_train_dataset.remove_columns([source_lang, target_lang])
tokenized_val_dataset = tokenized_val_dataset.remove_columns([source_lang, target_lang])

# %% [markdown]
# The tokenized datasets are then formatted to be compatible with PyTorch tensors, commonly used for training neural network models. The code specifies which columns should be included in the format, typically containing input IDs, attention masks, and labels necessary for model training

# %%
# Sets format for PyTorch
tokenized_train_dataset.set_format(type='torch', columns=['input_ids', 'attention_mask', 'labels'])
tokenized_val_dataset.set_format(type='torch', columns=['input_ids', 'attention_mask', 'labels'])

# %% [markdown]
# To facilitate convenient access and management of multiple datasets within a single object for seamless exploration during the training and evaluation process, the following code creates a unified object (tokenized_data). This object encompasses both the tokenized training and validation datasets, structured into a DatasetDict.

# %%
# Combines datasets into a DatasetDict
tokenized_data = DatasetDict({
    "train": tokenized_train_dataset,
    "validation": tokenized_val_dataset
})

# %% [markdown]
# ##Loading Model

# %% [markdown]
# The pipeline then prepares a pre-trained AfriMT5 model, specifically designed for machine translation tasks, to translate English text into Twi. By using the from_pretrained method with the identifier [AfriMT5](https://huggingface.co/masakhane/afri-mt5-base), the model is loaded from the Hugging Face model hub, making it readily available for translation tasks without the need for extensive training. Once initialized, the model is assigned to the variable model, enabling seamless translation from English to Twi.

# %%
# Initializes the model
model = AutoModelForSeq2SeqLM.from_pretrained("masakhane/afrimt5_en_twi_news")

# %% [markdown]
# ##Loading Evaluation Metrics

# %% [markdown]
# Defines a function named 'compute_metrics' used for evaluating the performance of the model during validation or testing. The function utilizes the BLEU scores to evaluate the performance of a machine translation model using predicted and ground truth translations.

# %%
# Defines compute_metrics function for evaluation
metric_bleu = evaluate.load("sacrebleu")

def compute_metrics(eval_pred):
    predictions, labels = eval_pred
    decoded_preds = tokenizer.batch_decode(predictions, skip_special_tokens=True)
    decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)

    # Calculates BLEU score
    bleu = metric_bleu.compute(predictions=decoded_preds, references=decoded_labels)

    return {"bleu": bleu["score"]}

# %% [markdown]
# ##Model Training & Evaluation of Validation Set

# %% [markdown]
# To efficiently train the model for machine translation, the below cell prepares the training environment for a sequence-to-sequence (seq2seq) model used in machine translation tasks. Firstly, it sets up a data collator to handle batching and preprocessing of training data. Then, it defines training arguments specifying parameters like output directory, evaluation strategy, learning rate, number of epochs, and batch sizes. Finally, it initializes the trainer with the model, training arguments, tokenized training and validation datasets, tokenizer, a function for computing evaluation metrics, and the data collator.

# %%
data_collator = DataCollatorForSeq2Seq(tokenizer, model=model)

# Defines training arguments
training_args = Seq2SeqTrainingArguments(
    output_dir="./results",
    eval_strategy="epoch",
    learning_rate=3e-5,
    per_device_train_batch_size=4,
    per_device_eval_batch_size=4,
    weight_decay=0.01,
    save_total_limit=2,
    num_train_epochs=1,
    predict_with_generate=True,
    gradient_accumulation_steps=2,   # accumulate gradients over 2 steps
    logging_dir='./logs',            # directory for storing logs
    logging_steps=10,
    save_steps=10,                   # save checkpoint every 10 steps
)

# Initializes the trainer
trainer = Seq2SeqTrainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_data["train"],
    eval_dataset=tokenized_data["validation"],
    tokenizer=tokenizer,
    compute_metrics=compute_metrics,
    data_collator=data_collator,
)

# %% [markdown]
# 'trainer.train()' initiates the training process, during which the model learns from the provided data to improve its performance. After training, 'trainer.save_model("afrimt5_translation_model")' saves the trained model to disk with the specified name "afrimt5_translation_model". This allows for future use of the model without the need for retraining.

# %%
try:
    trainer.train()
except RuntimeError as e:
    if "out of memory" in str(e):
        print("CUDA out of memory. Trying to clear memory and continue...")
        clear_memory()
        print_memory_usage()
        # Optionally, restart training from checkpoint if you have one
        trainer.train(resume_from_checkpoint=True)
    else:
        raise e
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/data/data_collator.py:646: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:274.)
#   batch["labels"] = torch.tensor(batch["labels"], dtype=torch.int64)
#     <div>
#
#       <progress value='2542' max='2542' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2542/2542 2:40:21, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Bleu</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.295500</td>
#       <td>0.257807</td>
#       <td>4.461024</td>
#     </tr>
#   </tbody>
# </table><p>
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1168: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(

# %%
# Save the model
trainer.save_model("afrimt5_translation_model")

# Clear memory after training
clear_memory()
print_memory_usage()
# Out:
# Clearing CUDA cache and running garbage collection...
# Memory cleared.
# Memory Usage: 2472.20 MB

# %% [markdown]
# ##Testing the Model

# %% [markdown]
# The below cell converts specific columns from a dataframe to Python lists and ensure that all elements within these lists are strings, which can be useful for further processing or analysis.

# %% [markdown]
# ####Data Preprocessing - Test Set

# %%
# Converts dataframe columns to python lists and ensure all entries are strings
test_english_sentences = [str(sentence) for sentence in df_test['English Sentence'].tolist()]
actual_twi_translations = [str(translation) for translation in df_test['Twi Translation'].tolist()]

# %% [markdown]
# ####Tokenization - Test Set

# %% [markdown]
# The pipeline then prepares the test dataset for evaluation by tokenizing English sentences and their corresponding Twi translations, then formatting them into PyTorch tensors. This ensures that the dataset is appropriately processed and ready for assessment of the model's performance on unseen data.

# %%
# Preprocess test dataset
test_dataset = Dataset.from_dict({"en": test_english_sentences, "twi": actual_twi_translations})
tokenized_test_dataset = test_dataset.map(lambda x: preprocess_function(x, tokenizer), batched=True)
tokenized_test_dataset.set_format(type='torch', columns=['input_ids', 'attention_mask', 'labels'])
# Out:
# Map:   0%|          | 0/695 [00:00<?, ? examples/s]

# %% [markdown]
# ####Evaluation on Test Dataset

# %% [markdown]
# Evaluates the model on the preprocessed test dataset, and prints the evaluation results, allowing the assessessment of the performance of the model on unseen data.

# %%
# Evaluate the model
results = trainer.evaluate(eval_dataset=tokenized_test_dataset)

# Print evaluation results

print(results)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1168: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
#     <div>
#
#       <progress value='174' max='174' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [174/174 01:47]
#     </div>
# {'eval_loss': 0.27802276611328125, 'eval_bleu': 1.817226196983961, 'eval_runtime': 108.56, 'eval_samples_per_second': 6.402, 'eval_steps_per_second': 1.603, 'epoch': 1.0}

# %% [markdown]
# The below code defines a function predict() that takes an English sentence, a model, a tokenizer, and a device as input parameters. Inside the function:
#
# It tokenizes the input English sentence using the provided tokenizer and ensures the tensors are on the specified device (GPU).
# The model generates predictions for the tokenized input using the generate() method.
# The predictions are decoded using the tokenizer to obtain the corresponding Twi sentence, which is returned as the output of the function.
# Before generating predictions, the code ensures that the model is on the correct device (GPU).
#
# Then, predictions are generated for each English sentence in the test_english_sentences list using the predict() function. The English sentence, predicted Twi sentence, and the actual Twi translation are printed for each pair in the dataset, allowing comparison between the predicted and actual translations.

# %%
# Defines a function to predict Twi sentences from English sentences
def predict(eng_sentence, model, tokenizer, device):
    # Tokenizes the input English sentence
    inputs = tokenizer(eng_sentence, return_tensors="pt").to(device)

    # Generates predictions using the model
    with torch.no_grad():
        outputs = model.generate(**inputs)

    # Decodes the predictions to get the Twi sentence
    predicted_twi_sentence = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return predicted_twi_sentence

# Ensures the model is on the correct device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

# Generates predictions
predicted_twi_sentences = [predict(eng, model, tokenizer, device) for eng in test_english_sentences]

# Prints English sentences, predicted Twi sentences, and actual Twi translations
for eng, twi_pred, twi_actual in zip(test_english_sentences, predicted_twi_sentences, actual_twi_translations):
    print(f"English: {eng}")
    print(f"Predicted Twi: {twi_pred}")
    print(f"Actual Twi: {twi_actual}")
    print()
# Out:
# English: What is going on here?
# Predicted Twi: Ɛyɛ akɔ hɔ?
# Actual Twi: Ɛdeɛn na  ɛrekɔso wɔ aha?
#
# English: Wake up
# Predicted Twi: Please
# Actual Twi: Sɔre
#
# English: She comes here every Friday
# Predicted Twi: Ɔrekɔ hɔ a ɛtɔ awie.
# Actual Twi: Ɔba ha Fiada biara
#
# English: Learn to be wise
# Predicted Twi: Ɛsɛ sɛ yɛn yɛ a yɛn a
# Actual Twi: Sua nyansa
#
# English: I didn’t think you would loose your way
# Predicted Twi: M'ani gye sɛ wobɛtɔ wo n'adwuma
# Actual Twi: Mannwene da sɛ wo bɛyera
#
# English: If you like to enter more than five pair of sentences for english
# Predicted Twi: Sɛ wopɛ sɛ wobɛka nsɛm a,
# Actual Twi: Sɛ wo pɛ sɛ wo tintim brɔfo ne twi nsɛmfua nnum ne akyire a
#
# English: My kids are worrying me.
# Predicted Twi: Me nnamfo no sɛ me n'ani.
# Actual Twi: Me mma reha m'adwene
#
# English: I am Simeon
# Predicted Twi: Ɔyɛ Simeon
# Actual Twi: Me ne Simeon
#
# English: Think about yourself
# Predicted Twi: Remember sɛ wore a superhero
# Actual Twi: Dwene wo ho
#
# English: This is good news
# Predicted Twi: Ɛyɛ a yɛn nsɛm.
# Actual Twi: Eyi yɛ asɛm papa
#
# English: Give that to your brother
# Predicted Twi: Ɔma wo papa no.
# Actual Twi: Fa ɛno ma wo nua barima no
#
# English: I love you
# Predicted Twi: -
# Actual Twi: Me dɔ wo
#
# English: Love is all we need
# Predicted Twi: Ɛno ne sɛ yɛn n'ani.
# Actual Twi: Ɔdɔ nko ara na yɛ hia
#
# English: How are you?
# Predicted Twi: Ɛhe?
# Actual Twi: Wo ho te sɛn?
#
# English: I love you
# Predicted Twi: -
# Actual Twi: Me dɔ wo
#
# English: I love you.
# Predicted Twi: Ɛnsɛ sɛ me n'ani.
# Actual Twi: Me dɔ wo.
#
# English: I like you very much
# Predicted Twi: Mepɛ wo nnɛ.
# Actual Twi: Me pɛ w'asɛm pa ara
#
# English: Come
# Predicted Twi: <extra_id_0>
# Actual Twi: bra
#
# English: Seeing is believing
# Predicted Twi: Ɛsɛ sɛ sɛ sɛ sɛ sɛ
# Actual Twi: Ɛsɛ w'ani
#
# English: It's been long I saw you
# Predicted Twi: Ɛnyɛ mfe a mehuu wo.
# Actual Twi: Mehunuu wo akyɛre
#
# English: Let's go and vote
# Predicted Twi: Ɛsɛ sɛ yɛnkɔ nkɔmmɔ.
# Actual Twi: Yɛnkɔ to aba
#
# English: How come your mother couldn't attend church ?
# Predicted Twi: W'abusua no n'abusua n'abus
# Actual Twi: 3baa no sɛn na wo Maame amma asɔre?
#
# English: Woman's vagina
# Predicted Twi: Female vagina
# Actual Twi: Ɔbaa twɛ
#
# English: What do you want here?
# Predicted Twi: Would worship here?
# Actual Twi: Ɛdeɛn na wo pɛ wɔ ha?
#
# English: Once bitten twice shy
# Predicted Twi: Once a n'ani a, n'ani a n
# Actual Twi: Deɛ ɔwɔ aka no suro sonsono
#
# English: Obedience is better that sacrifice
# Predicted Twi: Ɛsɛ sɛ sɛ ɔde n'abusu
# Actual Twi: Setie yɛ sen afɔrebɔ
#
# English: God have mercy on your children
# Predicted Twi: Ɛnyɛ sɛ ɔbɛma wo nkurɔfo.
# Actual Twi: Onyame hu wo mma mmɔbɔ
#
# English: Once bitten twice shy
# Predicted Twi: Once a n'ani a, n'ani a n
# Actual Twi: Deɛ ɔwɔ aka no suro sonsono
#
# English: They are tarnishing our image
# Predicted Twi: They n'ani ayɛ yɛn n'abusua
# Actual Twi: Wɔresɛe yɛn din
#
# English: I am tired
# Predicted Twi: -
# Actual Twi: Mabrɛ
#
# English: Take your time
# Predicted Twi: Ɛso sɛ w'ani.
# Actual Twi: To wo bo ase
#
# English: Do you love me?
# Predicted Twi: So wopɛ me?
# Actual Twi: Wo dɔ me?
#
# English: This is marvelous in our eyes
# Predicted Twi: Ɛyɛ a yɛn nsɛm a yɛn
# Actual Twi: Na yei yɛ nwanwa yɛn ani so
#
# English: I Love you
# Predicted Twi: -
# Actual Twi: Me dɔ wo
#
# English: me too
# Predicted Twi: a
# Actual Twi: Me nso saa ara
#
# English: villager
# Predicted Twi: a n'abusua
# Actual Twi: okuraseni
#
# English: I am going to school
# Predicted Twi: Ɛkɔ sukuu
# Actual Twi: Merekɔ sukuu
#
# English: How are you
# Predicted Twi: ?
# Actual Twi: ɛte sɛn
#
# English: sweet heart
# Predicted Twi: s
# Actual Twi: M'akoma mu tɔfe
#
# English: God’s Grace
# Predicted Twi: Blessings
# Actual Twi: Onyame adom
#
# English: Go and pluck some,it is sweet
# Predicted Twi: Ɛnyɛ sɛ ɔpɛ a, ɛyɛ s
# Actual Twi: Kɔte bi,ɛyɛ dɛ
#
# English: I’m hungry
# Predicted Twi: M'ani n'ani.
# Actual Twi: 3kɔm de me
#
# English: My name is Afia Serwaa
# Predicted Twi: Me nnamfo no Afia Serwaa
# Actual Twi: Me din de Afia Serwaa
#
# English: I’m going to be successful
# Predicted Twi: Ɛbɛyɛ me sɛ meyɛ a ɛsɛ sɛ
# Actual Twi: Mɛdi nkunim
#
# English: It pays to wait.
# Predicted Twi: Ɛsɛ sɛ ɔpɛ.
# Actual Twi: Abotrɛ wie nkunimdie
#
# English: That is amazing!
# Predicted Twi: Ɛyɛ a stunning!
# Actual Twi: Ɛyɛ me nwanwa!
#
# English: It is raining
# Predicted Twi: .
# Actual Twi: Osu retɔ
#
# English: He has leukaemia.
# Predicted Twi: Ɔwɔ n'abusua.
# Actual Twi: Ɔwɔ mogya mu kokram
#
# English: Come home.
# Predicted Twi: Please.
# Actual Twi: Bra fie.
#
# English: I'm going to buy oranges.
# Predicted Twi: Mɛbɛtɔ n'abusua.
# Actual Twi: Me rekɔtɔ ankaa.
#
# English: This is the money
# Predicted Twi: -
# Actual Twi: Sika no nie
#
# English: It is true
# Predicted Twi: Ɛno ara sɛ n'ani n'ani.
# Actual Twi: Ɛyɛ ampa
#
# English: What is your name?
# Predicted Twi: Ɛhe ne wo n'abusua?
# Actual Twi: Wo din de sen?
#
# English: Why
# Predicted Twi: - <extra_id_1>
# Actual Twi: Adɛn
#
# English: I am going to sleep
# Predicted Twi: Ɛnsɛ sɛ me n'ani n'ani
# Actual Twi: Merekɔ akɔ da
#
# English: Everything will be fine.
# Predicted Twi: Everything sẽ awie.
# Actual Twi: Biribiara bɛyɛ yie.
#
# English: Everything will be alright.
# Predicted Twi: Everything shall remain a row.
# Actual Twi: Biribiara bɛyɛ yie.
#
# English: please
# Predicted Twi:
# Actual Twi: Mepa wo kyɛw
#
# English: everyone is well
# Predicted Twi: n'asram no,
# Actual Twi: obiara ho yɛ
#
# English: it is well
# Predicted Twi:
# Actual Twi: na ɛyɛ
#
# English: food is ready
# Predicted Twi: When a strawberry a
# Actual Twi: yɛasiesie aduane ama wo
#
# English: would you like to retire now?
# Predicted Twi: Would w'ani pɛ sɛ wopɛ sɛ wode
# Actual Twi: wo pɛ sɛ wobɛhome kakra?
#
# English: What's your name?
# Predicted Twi: Ɛhe ne wo n'akyi?
# Actual Twi: Wo din de sɛn?
#
# English: What's your name?
# Predicted Twi: Ɛhe ne wo n'akyi?
# Actual Twi: Yɛfrɛ wo sɛn?
#
# English: How are you called?
# Predicted Twi: Ɛhe na woa ayɛ?
# Actual Twi: Yɛfrɛ wo sɛn?
#
# English: good morning
# Predicted Twi: a <extra_id_1>
# Actual Twi: maakye
#
# English: good morning
# Predicted Twi: a <extra_id_1>
# Actual Twi: mema wo akye
#
# English: see you later
# Predicted Twi: sɛ me n'ani awie
# Actual Twi: akyire
#
# English: i am from Australia
# Predicted Twi: i am Australia
# Actual Twi: mefiri Australia
#
# English: i came on a visit
# Predicted Twi: i went to a n'abusua.
# Actual Twi: mebaa nsrahwɛ wɔ ha
#
# English: how long have you been here?
# Predicted Twi: Ɔkwan a worekɔ hɔ?
# Actual Twi: wobaa ha akyɛ?
#
# English: let's go to church
# Predicted Twi: yɛnkɔ kɔkɔɔ kɔkɔɔ kɔkɔɔ
# Actual Twi: ma yɛnkɔ asɔre
#
# English: let's go to church
# Predicted Twi: yɛnkɔ kɔkɔɔ kɔkɔɔ kɔkɔɔ
# Actual Twi: yɛnkɔ asɔre
#
# English: we are going for a drink
# Predicted Twi: yɛn bɛkɔ a ɔbɛkɔ a ɔbɛkɔ
# Actual Twi: yɛrekɔ pɛ biribi anom
#
# English: we are going to look for something to drink
# Predicted Twi: yɛbɛhyɛ biribi a ɛbɛbɔ a ɛbɛ
# Actual Twi: yɛrekɔ pɛ biribi anom
#
# English: i'm here
# Predicted Twi: i'm here
# Actual Twi: mewɔ ha
#
# English: i'm full
# Predicted Twi: i'm a
# Actual Twi: mamen
#
# English: rainy season
# Predicted Twi: a few
# Actual Twi: nsutɔ berɛ
#
# English: it is sunny
# Predicted Twi: sɛ sunny
# Actual Twi: awia abɔ
#
# English: this is pretty
# Predicted Twi: nnwɛ sɛ nnwɛ nnwɛ
# Actual Twi: adeɛ yi yɛ fɛ
#
# English: your offer is too low, give me 7 cedis
# Predicted Twi: W'adwene a wo sika no yɛ ɔhaw a ɛ
# Actual Twi: ɛwɔ fam dodo, ma me 7 cedis
#
# English: we have become friends
# Predicted Twi: yɛn n'abusua a yɛn n'a
# Actual Twi: yɛayɛ nnamfoɔ
#
# English: I am running to school.
# Predicted Twi: M'ani kɔɔ sukuu.
# Actual Twi: Meredwane akɔ sukuu.
#
# English: Dance
# Predicted Twi: <extra_id_0>
# Actual Twi: Di asa
#
# English: dance
# Predicted Twi: a
# Actual Twi: sa
#
# English: School children go to school from Monday to Friday
# Predicted Twi: Ɔkwan a wɔkɔ sukuu no kɔ sukuu kɔɔ suku
# Actual Twi: Sukuufoɔ kɔ sukuu firi Dwoada kɔsi Fiada
#
# English: School children go to school from Monday to Friday
# Predicted Twi: Ɔkwan a wɔkɔ sukuu no kɔ sukuu kɔɔ suku
# Actual Twi: Sukuu nkwadaa kɔ sukuu firi Dwoada kɔsi Fiada
#
# English: Who is it?
# Predicted Twi: Where?
# Actual Twi: hwan nono?
#
# English: Who is that?
# Predicted Twi: Ɔbaa a?
# Actual Twi: hwan nono?
#
# English: Who are you?
# Predicted Twi: Where?
# Actual Twi: woyɛ hwan?
#
# English: Is the path straight?
# Predicted Twi: So sɛ n'aso no sɔ?
# Actual Twi: ɛkwan no tene
#
# English: Please help us to do our work.
# Predicted Twi: Please yɛn sɛ yɛyɛ yɛn ayɛ yɛ
# Actual Twi: Mepa wo kyɛw, boa yɛn na yɛnyɛ yɛn adwuma.
#
# English: Jesus is Great.
# Predicted Twi: Yesu a Bless.
# Actual Twi: Yesu yɛ kɛse
#
# English: You are beautiful
# Predicted Twi: Would be
# Actual Twi: Wo ho yɛ fɛ
#
# English: Are you asleep?
# Predicted Twi: So woae?
# Actual Twi: Woada anaa?
#
# English: Can I send you ?
# Predicted Twi: Bisa me?
# Actual Twi: Mɛtumi asoma wo ?
#
# English: I work here
# Predicted Twi: - <extra_id_1>
# Actual Twi: Meyɛ adwuma wɔ ha
#
# English: How are you?
# Predicted Twi: Ɛhe?
# Actual Twi: Ɛte sɛn?
#
# English: I'm good
# Predicted Twi: M'ani gye
# Actual Twi: Me ho yɛ
#
# English: Come to Jesus
# Predicted Twi: Ɛsɛ sɛ ɔbɛma
# Actual Twi: Bra Yesu nkyɛn
#
# English: My name is.....
# Predicted Twi: Me no sɛ me no
# Actual Twi: Me din de.......
#
# English: Why are you looking at me like that?
# Predicted Twi: Ɛyɛ sɛ wopɛ me sɛ wopɛ me?
# Actual Twi: Adɛn nti na worehwɛ me saa?
#
# English: I am serious
# Predicted Twi: Ɛnsɛ sɛ me n'ani a n'ani
# Actual Twi: m'ani abre
#
# English: There are a lot of people in this city
# Predicted Twi: Ɛnyɛ nnipa a wɔwɔ awiei mu.
# Actual Twi: kuropɔn yi mu nipa dɔɔso
#
# English: There are a lot of people in this city
# Predicted Twi: Ɛnyɛ nnipa a wɔwɔ awiei mu.
# Actual Twi: nipa bebree wɔ kuro yi mu
#
# English: Let's go to the market to buy some vegetables
# Predicted Twi: Ɛnyɛ sɛ yɛkɔ ɔman no mu a yɛ
# Actual Twi: Yɛnkɔ dwam nkɔ tɔ atosodeɛ
#
# English: Pour the water into the bucket
# Predicted Twi: Remove a bottle to a bucket.
# Actual Twi: Hwie nsuo no gu bokiti no mu
#
# English: Man's penis
# Predicted Twi: Penis
# Actual Twi: Barima kɔte
#
# English: Stop playing the game.
# Predicted Twi: Please n'ani n'ani.
# Actual Twi: Gyae saa agorɔ no di.
#
# English: God help those who help themselves
# Predicted Twi: Ɔba nnipa a ɔba nnipa a ɔba
# Actual Twi: Onyame boa wɔn a wɔboa wɔn ho
#
# English: Take that pen to your father
# Predicted Twi: Ɛsɛ sɛ wo papa bɛka saa nsɛm
# Actual Twi: Fa saa twerɛdua no kɔ ma wo papa
#
# English: God tempers the wind to the shorn lamb
# Predicted Twi: Ɔso a ɔde n'abusua no a
# Actual Twi: Aboa a ɔnni dua Onyame na ɔpra ne ho
#
# English: God help those who help themselves
# Predicted Twi: Ɔba nnipa a ɔba nnipa a ɔba
# Actual Twi: Onyame boa wɔn a wɔboa wɔn ho
#
# English: You don't know him
# Predicted Twi: W'ani nnim no
# Actual Twi: Wonnim no
#
# English: I am happy
# Predicted Twi: '
# Actual Twi: M'ani agye
#
# English: I don’t have money
# Predicted Twi: M'ani nnɔ sika
# Actual Twi: Menni sika
#
# English: This was the Lord's doing
# Predicted Twi: Ɛno ne ɔbarima no a ɔde ayɛ.
# Actual Twi: Awurade na ɔmaa yei baeɛ
#
# English: I shall sleep
# Predicted Twi: sɛ me n'ani sɔ
# Actual Twi: Mɛda
#
# English: count me in
# Predicted Twi: sɛ me n'adwuma
# Actual Twi: fa me ka ho
#
# English: who do you think you are?
# Predicted Twi: Wususuw sɛ woyɛ nea w'ani a?
# Actual Twi: wo dwene sɛ wo yɛ hwan?
#
# English: I am going to church
# Predicted Twi: Ɛkɔ kɔkɔkɔkɔkɔ
# Actual Twi: Merekɔ asɔre
#
# English: God bless you
# Predicted Twi: Bless wo
# Actual Twi: Nyame nhyira wo
#
# English: Your love is to die for
# Predicted Twi: W'abusua no sɛ wobɛfa.
# Actual Twi: ɔdɔ yɛ wu
#
# English: If it weren’t for God
# Predicted Twi: Sɛ ɛyɛ sɛ ɔyɛ ɔman no, ɛnyɛ
# Actual Twi: Sɛ ɛnyɛ Nyame a
#
# English: The love of my life
# Predicted Twi: -
# Actual Twi: Medɔ wiase
#
# English: I love my life
# Predicted Twi: -
# Actual Twi: Medɔ me nkwa
#
# English: God bless you
# Predicted Twi: Bless wo
# Actual Twi: Onyame nhyira wo
#
# English: I stay at Mampong
# Predicted Twi: M'abusua no
# Actual Twi: Mete Mampong
#
# English: I have prayed three times already.
# Predicted Twi: M'ani n'ani n'ani n'ani n'ani
# Actual Twi: Mabɔ mpae mprɛnsa dada.
#
# English: What a surprise!
# Predicted Twi: WOW!
# Actual Twi: Afu me mu!
#
# English: I have been surprised
# Predicted Twi: Ɛnyɛ me sɛ me n'ani awie.
# Actual Twi: Afu me mu!
#
# English: I am going to work
# Predicted Twi: M'ani bɛkɔ so.
# Actual Twi: Merekɔ adwuma
#
# English: Drink water.
# Predicted Twi:
# Actual Twi: Nom nsuo.
#
# English: How are you?
# Predicted Twi: Ɛhe?
# Actual Twi: Ɛte sɛn?
#
# English: The child is asleep
# Predicted Twi: Ɔbaa no sɔ.
# Actual Twi: Akwadaa no ada
#
# English: This is the truth
# Predicted Twi: Ɛno yɛ sɛ n'ani.
# Actual Twi: Nokware no nie
#
# English: How old are you?
# Predicted Twi: Ɔhow a woa?
# Actual Twi: Woadi  mfeɛ sen?
#
# English: Fool
# Predicted Twi: - <extra_id_1>
# Actual Twi: Kwasea
#
# English: How are you?
# Predicted Twi: Ɛhe?
# Actual Twi: Ɛte sɛn?
#
# English: How are you doing?
# Predicted Twi: Ɛhe na woyɛ?
# Actual Twi: Ɛte sɛn?
#
# English: thank you
# Predicted Twi:
# Actual Twi: medaase
#
# English: please can i offer you some water?
# Predicted Twi: sɛ meboa wo nsɛntwerɛ?
# Actual Twi: mepa wo kyɛw memmrɛ wo nsuo?
#
# English: what is the purpose of your visit?
# Predicted Twi: Ɛhe ne sɛnea wo n'adwuma no bɛ
# Actual Twi: ɛha deɛ bɔkɔɔ, wona wonam
#
# English: what is the purpose of your visit?
# Predicted Twi: Ɛhe ne sɛnea wo n'adwuma no bɛ
# Actual Twi: wo nsrahwɛ no mu botae ne sɛn?
#
# English: let me show you to your room
# Predicted Twi: bɛma me n'ani kɔ wo n'adwuma.
# Actual Twi: ma menkyerɛ wo baabi a wobɛda
#
# English: young woman
# Predicted Twi: a <extra_id_1>
# Actual Twi: ababaawa
#
# English: What's your age?
# Predicted Twi: Ɛhe ne wo age?
# Actual Twi: Woadi mfie sɛn?
#
# English: What's your age?
# Predicted Twi: Ɛhe ne wo age?
# Actual Twi: Wo mfie yɛ sɛn?
#
# English: How old are you?
# Predicted Twi: Ɔhow a woa?
# Actual Twi: Woadi mfie sɛn?
#
# English: good afternoon
# Predicted Twi: a
# Actual Twi: maaha
#
# English: what is your name?
# Predicted Twi: sɛnea wo ne no?
# Actual Twi: yɛfrɛ wo sɛn?
#
# English: what about you?
# Predicted Twi: ?
# Actual Twi: na wo nso ɛ?
#
# English: where do you live?
# Predicted Twi: Where do w'adwuma?
# Actual Twi: wote he?
#
# English: when will you go back?
# Predicted Twi: When a worekɔ?
# Actual Twi: da bɛn na wobɛ san akɔ?
#
# English: let's go to town
# Predicted Twi: yɛnkɔ kɔɔ kɔɔ kɔɔ
# Actual Twi: ma yɛnkɔ kurom
#
# English: lets go for a taxi
# Predicted Twi: sɛ yɛn nkɔ taxi a, nkɔ
# Actual Twi: ma yɛnkɔ fa taxi
#
# English: i'm tired
# Predicted Twi: i'm tired
# Actual Twi: mabrɛ
#
# English: i'm drunk
# Predicted Twi: i'm a
# Actual Twi: maboro nsa
#
# English: dry season
# Predicted Twi: a
# Actual Twi: ɔpɛ berɛ
#
# English: the weather is warm
# Predicted Twi: a
# Actual Twi: ɔhyew wɔ mu
#
# English: can i buy it?
# Predicted Twi: sɛ i n'ani awie?
# Actual Twi: metumi atɔ anaa?
#
# English: it is still too high, what is your last price
# Predicted Twi: ɛno ara a ɛte sɛ ɛyɛ sika
# Actual Twi: ɛda so wɔ soro, ne korakora ne sɛn
#
# English: come back next time
# Predicted Twi: a n'ani awie.
# Actual Twi: san bra da foforo
#
# English: wait for me!
# Predicted Twi: sɛ me n'adwuma!
# Actual Twi: Twɛn me!
#
# English: I'm sleepy
# Predicted Twi: Me n'ani n'ani
# Actual Twi: M'ani kum
#
# English: The strong wind destroyed many thatched houses
# Predicted Twi: Ɔkwan a ɛtɔ nsu no awiei
# Actual Twi: Ahum no pepaa daha dan bebree so
#
# English: You may confide in me
# Predicted Twi: Would believe me.
# Actual Twi: Nya awerɛhyɛmu wɔ me mu
#
# English: You may disclose it to me.
# Predicted Twi: Wɔbɛka sɛ wobɛka sɛ wobɛka.
# Actual Twi: ka kyerɛ me
#
# English: Is the river wide?
# Predicted Twi: So a row a row no awie?
# Actual Twi: Asuo no so?
#
# English: Give it to God
# Predicted Twi: Ɔso sɛ ɔbɛma no.
# Actual Twi: Fa ma Nyame
#
# English: The cat has ran away
# Predicted Twi: Ɔman no awie.
# Actual Twi: ɔkra no aguan kɔ
#
# English: Be wary of those close to you
# Predicted Twi: Ɛnyɛ sɛ wo ne nnipa a wo ho a wo
# Actual Twi: Suro nea ɔbɛn wo
#
# English: Come let's play
# Predicted Twi: Ɛba yɛn n'ani akɔ.
# Actual Twi: Bra ma yɛnni agorɔ
#
# English: I am good
# Predicted Twi: Ɛnyɛ me
# Actual Twi: Me ho yɛ
#
# English: Where are you?
# Predicted Twi: Where?
# Actual Twi: Wowɔ he?
#
# English: Where are you?
# Predicted Twi: Where?
# Actual Twi: wowɔ hefa?
#
# English: Sin
# Predicted Twi: a <extra_id_1>
# Actual Twi: Bɔne
#
# English: I am a Ghanaian.
# Predicted Twi: M'ani Ghanafo.
# Actual Twi: Me yɛ Gaanani.
#
# English: Is that so?
# Predicted Twi: Ɛyɛ saa?
# Actual Twi: Saa?
#
# English: i'm wild
# Predicted Twi: i'm a
# Actual Twi: m'ani abre
#
# English: It's a new day
# Predicted Twi: Ɛyɛ a n'ani gye.
# Actual Twi: Ade akye abia
#
# English: Too much Fat is bad for the body
# Predicted Twi: Ɛnyɛ sɛ sɛ a n'ani n'
# Actual Twi: Sradeɛ bebree nyɛ ma nipadua no
#
# English: When are you coming to visit us?
# Predicted Twi: Ɛnnɛ sɛ wobɛkɔ us?
# Actual Twi: Dabɛn na wobɛba abɛsra yɛn?
#
# English: My love
# Predicted Twi: ' <extra_id_1>
# Actual Twi: Me dɔ!
#
# English: I will build my house in three months.
# Predicted Twi: Mɛsoa me fie a ɛtɔ mfe a ɛ
# Actual Twi: Me de bosome miensa bɛsi me dan no.
#
# English: Two heads are better than one
# Predicted Twi: Ɛnyɛ sɛ n'abusua no a,
# Actual Twi: Tikorɔ nkɔ agyina
#
# English: Two heads are better than one
# Predicted Twi: Ɛnyɛ sɛ n'abusua no a,
# Actual Twi: Ti mmienu yɛ sene baako
#
# English: Look before you leap
# Predicted Twi: Ɛnsɛ sɛ wo n'ani akɔ.
# Actual Twi: Hwɛ ansa na woahuri
#
# English: Good things come from above
# Predicted Twi: Ɛno a ɛyɛ a ɛyɛ a ɛyɛ.
# Actual Twi: Nnepa firi soro
#
# English: Two heads are better than one
# Predicted Twi: Ɛnyɛ sɛ n'abusua no a,
# Actual Twi: Ti korɔ nkɔ agyina
#
# English: I'm confused.
# Predicted Twi: M'ani n'ani.
# Actual Twi: Mente aseɛ
#
# English: I don't understand it
# Predicted Twi: M'ani gyee
# Actual Twi: Mente aseɛ
#
# English: I like you
# Predicted Twi: Ɛpɛ wo
# Actual Twi: Me pɛ w'asem
#
# English: How much is it?
# Predicted Twi: Ɛno a ɛwɔ?
# Actual Twi: Ɛyɛ sɛn?
#
# English: How much is it?
# Predicted Twi: Ɛno a ɛwɔ?
# Actual Twi: Ne boɔ yɛ sɛn?
#
# English: What is the price?
# Predicted Twi: Ɛhe ne sika?
# Actual Twi: Ne boɔ yɛ sɛn?
#
# English: Have you not read this scripture?
# Predicted Twi: So woakyerɛw saa sɛ wobɛka saa s
# Actual Twi: Nti monkenkanee atwerɛ yi pɛn?
#
# English: Can I have some water
# Predicted Twi: Bisa me a nsɛntwer?
# Actual Twi: Metumi anya nsuo
#
# English: Can I have some water
# Predicted Twi: Bisa me a nsɛntwer?
# Actual Twi: Menya nsuo
#
# English: i don't want any trouble
# Predicted Twi: n'ani pɛ sɛ n'ani nnye n'
# Actual Twi: mempɛ asɛm
#
# English: what do you take me for?
# Predicted Twi: Would me a n'ani?
# Actual Twi: wohu me sɛn?
#
# English: How do you see me?
# Predicted Twi: Wususuw me?
# Actual Twi: wohu me sɛn?
#
# English: Call her for me
# Predicted Twi: Please sn'abusua
# Actual Twi: Frɛ no ma me
#
# English: Call him for me
# Predicted Twi: Please srɛ no
# Actual Twi: Frɛ no ma me
#
# English: sorry
# Predicted Twi: <extra_id_0>
# Actual Twi: kafra
#
# English: I’m from Ghana
# Predicted Twi: M'ani Ghana
# Actual Twi: Mefiri Ghana
#
# English: I am the light of the world
# Predicted Twi: Me yɛ n'ani a ɔwɔ n'ani.
# Actual Twi: Me ne wiase kanea no
#
# English: Ama is dancing
# Predicted Twi: -
# Actual Twi: Ama resa
#
# English: I'm a student
# Predicted Twi: M'ani a graduate
# Actual Twi: Meyɛ osuani
#
# English: This child is smart.
# Predicted Twi: Ɛyɛ a n'ani gye.
# Actual Twi: Abɔfra yi nim adeɛ.
#
# English: My name is Kwame
# Predicted Twi: Kwame no yɛ me.
# Actual Twi: Me din de Kwame
#
# English: Eat your food.
# Predicted Twi: Ɛnsɛ sɛ w'abusua.
# Actual Twi: Di w’aduane no.
#
# English: I'm two years old
# Predicted Twi: Mewɔ mfe a ɛtɔ.
# Actual Twi: Madi mfie mmienu
#
# English: Lie
# Predicted Twi: - <extra_id_1>
# Actual Twi: Ntorɔ
#
# English: Where's the church building located?
# Predicted Twi: Where a n'abusua no akɔ?
# Actual Twi: Asɔre dan no wɔ hefa?
#
# English: Adwene
# Predicted Twi: a a
# Actual Twi: Mind
#
# English: Welcome
# Predicted Twi: <extra_id_0>
# Actual Twi: Akwaaba
#
# English: how are you?
# Predicted Twi: Where?
# Actual Twi: wo ho te sɛn?
#
# English: yes, thank you
# Predicted Twi: yɛn sɛ wo,
# Actual Twi: aane, medaase
#
# English: what's up
# Predicted Twi: n'ani a n'ani
# Actual Twi: amaneɛ
#
# English: let us go out for a drink
# Predicted Twi: yɛnkɔ kɔkɔ kɔkɔ kɔkɔ kɔkɔ kɔkɔ
# Actual Twi: ma yenkɔ pɛ biribi nnom
#
# English: see you later
# Predicted Twi: sɛ me n'ani awie
# Actual Twi: akyire yi
#
# English: What's the time
# Predicted Twi: When's a n'adwuma?
# Actual Twi: Abɔ sɛn?
#
# English: good evening
# Predicted Twi: a
# Actual Twi: maadwo
#
# English: my name is kwasi
# Predicted Twi: Kwasi me no n'ani n'ani
# Actual Twi: yɛfrɛ me kwasi
#
# English: why are you in Ghana?
# Predicted Twi: Ghana?
# Actual Twi: wobɛyɛɛ dɛn wɔ Ghana?
#
# English: i live at Bolga
# Predicted Twi: i lived at Bolga
# Actual Twi: mete Bolga
#
# English: i will leave tomorrow
# Predicted Twi: i'm n'abusua tomorrow
# Actual Twi: mɛkɔ ɔkyena
#
# English: lets go out
# Predicted Twi: sɛ yɛn nkɔ
# Actual Twi: mayɛn mpue
#
# English: i prefer the bus
# Predicted Twi: i would nt forget
# Actual Twi: anka mepɛ sɛ mefa trɔtrɔ
#
# English: i'm sleepy
# Predicted Twi: i'm a
# Actual Twi: m'ani kum
#
# English: i love you
# Predicted Twi: i <extra_id_1>
# Actual Twi: medɔ wo
#
# English: harmattan season
# Predicted Twi: a ɛsɛ sɛ a ɛsɛ sɛ
# Actual Twi: ɔpɛ berɛ
#
# English: the weather is cold
# Predicted Twi: a
# Actual Twi: awɔ wom
#
# English: how much is it?
# Predicted Twi: ?
# Actual Twi: ɛyɛ sɛn?
#
# English: okay, you give me 6 cedis
# Predicted Twi: Wɔde me n'ani a ɛsɛ sɛ wo
# Actual Twi: ɛyɛ, wo deɛ mame 6 cedis
#
# English: come back for another business
# Predicted Twi: n'adwuma no a ɛrekɔ so.
# Actual Twi: san bra biom ma yenni dwa
#
# English: I'm happy
# Predicted Twi: M'ani gye
# Actual Twi: M'ani agye
#
# English: Good morning
# Predicted Twi: a <extra_id_1>
# Actual Twi: Mema wo akye
#
# English: Who did this or that?
# Predicted Twi: Ɔbaa nea ɔkaa?
# Actual Twi: hwan na ɔyɛɛ  wei, anaa ɔyɛɛ saa?
#
# English: Is it very deep?
# Predicted Twi: So sɛ ɛyɛ a ɛyɛ?
# Actual Twi: Emu dɔ?
#
# English: You are doing a good job.
# Predicted Twi: W'ani gye a yɛn n'adwuma.
# Actual Twi: Moreyɛ adwuma pa
#
# English: I have been searching for too long
# Predicted Twi: Since a few weeks ago, me n'ani n'ani
# Actual Twi: Mahwehwɛ  akyɛ
#
# English: The Twi language has so many words
# Predicted Twi: Ɛyɛ nsɛm a ɛwɔ nsɛm yi
# Actual Twi: Twi kasa wɔ nsemfua pii
#
# English: Do this for me
# Predicted Twi: Ɛyɛ me?
# Actual Twi: Yɛ wei ma me
#
# English: Are you hungry?
# Predicted Twi: So woa sɔre?
# Actual Twi: Ɛkɔm de wo?
#
# English: Good morning to you
# Predicted Twi: Bless me
# Actual Twi: Mema wo akye
#
# English: Food
# Predicted Twi: <extra_id_0>
# Actual Twi: Aduane
#
# English: The capital of Ghana is Accra.
# Predicted Twi: Ghana a ɔman no a ɛwɔ Accra.
# Actual Twi: Ghana ahenkuro yɛ Nkran.
#
# English: How are you?
# Predicted Twi: Ɛhe?
# Actual Twi: Ɛte sen?
#
# English: I've graduated from university
# Predicted Twi: Me graduated university
# Actual Twi: Mawie sukuu pɔn
#
# English: I am hungry
# Predicted Twi: -
# Actual Twi: Kɔm de me
#
# English: Yaw Obeng is a cheat.
# Predicted Twi: Yɛw Obeng yɛ n'adwuma.
# Actual Twi: Yaw Danso yɛ sisifoɔ
#
# English: Schooling is necessary for children's education.
# Predicted Twi: Ɛsɛ sɛ sɛ ɔbɛyɛ a n'
# Actual Twi: Sukuu kɔ hia ma nkɔdaa adesua.
#
# English: He who is down fears no fall
# Predicted Twi: Ɔbaa a ɔrekɔ no n'ani n'ani
# Actual Twi: Deɛ ɔda fam no nsuro ahweaseɛ
#
# English: Empty barrel makes the most sound
# Predicted Twi: Empty barrel a few inches a row a row
# Actual Twi: Ahwene pa nkasa
#
# English: As a man thinks so he is
# Predicted Twi: Sɛ a n'ani sɛ a, sɛ a
# Actual Twi: Sɛdeɛ onipa dwene no saa ara na ɔteɛ
#
# English: He who is down fears no fall
# Predicted Twi: Ɔbaa a ɔrekɔ no n'ani n'ani
# Actual Twi: Deɛ ɔda fam no nsuro ahweaseɛ
#
# English: We have a name to protect
# Predicted Twi: Ɛwɔ n'adwuma a yɛde ayɛ.
# Actual Twi: Ɛsɛsɛ yɛbɔ yɛn din ho ban
#
# English: I love you
# Predicted Twi: -
# Actual Twi: Me dɔ wo
#
# English: What work do you do?
# Predicted Twi: Wouldayɛ?
# Actual Twi: Edwuma bɛn na wo yɛ?
#
# English: John said to them
# Predicted Twi: John kyerɛɛɛ wɔn.
# Actual Twi: Na John bua see wɔn sɛ
#
# English: I am ashamed
# Predicted Twi: Ɛnyɛ me sɛ me n'ani n'ani
# Actual Twi: M'ani awu
#
# English: feel free and go ahead
# Predicted Twi: sɛ u n'ani nnye, n'ani n
# Actual Twi: Ɛkwan ne w'anim
#
# English: you don't respect
# Predicted Twi: W'ani n'ani n'ani
# Actual Twi: wommu adeɛ
#
# English: Can we talk?
# Predicted Twi: Ɛsɛ sɛ yɛn nkɔ?
# Actual Twi: Yɛbɛ tumi akasa anaa?
#
# English: My sympathies to you
# Predicted Twi: Me n'ani gye wo.
# Actual Twi: mesu ma wo
#
# English: How old are you?
# Predicted Twi: Ɔhow a woa?
# Actual Twi: Woadi mfie sɛn?
#
# English: Have you eaten?
# Predicted Twi: ?
# Actual Twi: Woadidi?
#
# English: This child is wise.
# Predicted Twi: Ɛyɛ a n'ani gye.
# Actual Twi: Abofra yi nim nyansa.
#
# English: I was born on Saturday
# Predicted Twi: Ɔkwan a ɛtɔ so.
# Actual Twi: Wɔwoo me Memeneda
#
# English: Switch on the light.
# Predicted Twi: -
# Actual Twi: Sɔ kanea no.
#
# English: Where do you stay?
# Predicted Twi: Where do w'adwuma?
# Actual Twi: Wo te he?
#
# English: There is no way
# Predicted Twi: Ɛno nti.
# Actual Twi: Kwan nni ha
#
# English: Let's play a game
# Predicted Twi: Ɛnyɛ sɛ yɛnyɛ a yɛde a
# Actual Twi: Ma yenni agorɔ
#
# English: Work
# Predicted Twi: <extra_id_0>
# Actual Twi: Adwuma
#
# English: Yes
# Predicted Twi: <extra_id_0>
# Actual Twi: Aane
#
# English: i am fine, thank you
# Predicted Twi: i am a few,
# Actual Twi: me ho yɛ, medaase
#
# English: no, thank you
# Predicted Twi: n'ani,
# Actual Twi: daabi, medaase
#
# English: i am just visiting
# Predicted Twi: i am a few weeks ago
# Actual Twi: mebɛsraa mo
#
# English: you must be tired
# Predicted Twi: sɛ w'ani n'ani n'ani.
# Actual Twi: mehwɛ a wabrɛ
#
# English: wake up
# Predicted Twi:
# Actual Twi: sɔre
#
# English: Call me your Dad.
# Predicted Twi: Please, sɛ wo Dad.
# Actual Twi: Frɛ wo papa ma me
#
# English: good night
# Predicted Twi: a <extra_id_1>
# Actual Twi: da yie
#
# English: where are you from?
# Predicted Twi: Where a wo a?
# Actual Twi: wofri he?
#
# English: i'm here on business
# Predicted Twi: i'm a ɛrekɔ n'adwuma.
# Actual Twi: mebɛyɛɛ adwuma
#
# English: where do you work?
# Predicted Twi: Where do w'adwuma?
# Actual Twi: woyɛ adwuma wɔ he?
#
# English: lets go and eat
# Predicted Twi: sɛ yɛn kɔ kɔ
# Actual Twi: ma yɛnkɔ didi
#
# English: where are we going?
# Predicted Twi: Where a yɛrekɔ?
# Actual Twi: yɛrekɔ he?
#
# English: i am looking for you
# Predicted Twi: i am looking for wo
# Actual Twi: merehwehwɛ wo
#
# English: i'm thirsty
# Predicted Twi: i'm srw'
# Actual Twi: sukɔm de me
#
# English: i miss you
# Predicted Twi: i mrw wo
# Actual Twi: m'ani agyina wo
#
# English: cloudy season
# Predicted Twi: a
# Actual Twi: ɛbɔ
#
# English: morning time
# Predicted Twi: a <extra_id_1>
# Actual Twi: ade akye
#
# English: give me 10 cedis
# Predicted Twi: bɛma me nnɔsa
# Actual Twi: ma me 10 cedis
#
# English: i will take it, thanks
# Predicted Twi: i'm n'ani n'ani,
# Actual Twi: mɛfa no saa ara, medaase
#
# English: you have really helped me, thank you
# Predicted Twi: yɛn a yɛde me awie, sɛ wo yɛ
# Actual Twi: woaboa me pa ara, medaase
#
# English: Goodbye
# Predicted Twi: Ɛsɛ sɛ yɛn nsɛm
# Actual Twi: Nante yie o!
#
# English: I have no idea
# Predicted Twi: M'ani gye.
# Actual Twi: Menni ho nimdeɛ biara.
#
# English: Is there a bridge on it ?
# Predicted Twi: So a nsu a ɛwɔ?
# Actual Twi: ɛtwene da so?
#
# English: I have no idea
# Predicted Twi: M'ani gye.
# Actual Twi: Mennim ho akwankyerɛ biara .
#
# English: Not conversant with Twi, I wrote fante.
# Predicted Twi: M'ani gye n'ani gye n'ani gye n
# Actual Twi: Me nte twi papa, me twerɛɛ fante.
#
# English: The world is becoming scary.
# Predicted Twi: Ɛnyɛ a n'ani a n'ani a
# Actual Twi: Wiase ayɛ hu
#
# English: The Lord is my shepherd
# Predicted Twi: Ɔba no yɛ me n'abusua
# Actual Twi: Awurade ne me guanhwɛfoɔ
#
# English: Sit down
# Predicted Twi: sn <extra_id_1>
# Actual Twi: Tena ase
#
# English: I’m craving for Rice
# Predicted Twi: M'ani gye Rice.
# Actual Twi: Mekɔndɔ  ɛmo
#
# English: Education is good
# Predicted Twi: Economics a few
# Actual Twi: Nwomasua yɛ
#
# English: Music
# Predicted Twi: <extra_id_0>
# Actual Twi: Nnwom
#
# English: God is king.
# Predicted Twi: Ɔman no n'abusua.
# Actual Twi: Nyame ne hene.
#
# English: I am okay
# Predicted Twi: Ɛnyɛ me.
# Actual Twi: ɛyɛ
#
# English: I will tell my friends about this platform
# Predicted Twi: M'ani bɛka me nnamfo a wɔde ayɛ a
# Actual Twi: Mɛka dabre yi ho asem akyerɛ me nnamfo
#
# English: How are you?
# Predicted Twi: Ɛhe?
# Actual Twi: Ɛtesen
#
# English: Call your dad for me because it getting late
# Predicted Twi: Please, sɛ wo papa akɔ me a, ɛsɛ
# Actual Twi: Frɛ wo papa ma me na adeɛ resa
#
# English: What items are you travelling with?
# Predicted Twi: Would you a few a ɛwɔ a ɛwɔ?
# Actual Twi: Ɛdeɛn nnoɔma na wo de retu kwan no?
#
# English: All days are not equal
# Predicted Twi: Ɛnsɛ sɛ nnɛ nnɛ nn
# Actual Twi: Mmerɛ nyinaa nsɛ
#
# English: God bless you
# Predicted Twi: Bless wo
# Actual Twi: Onyame nhyira wo
#
# English: Tomorrow is another day
# Predicted Twi: Tomorrow a few days ago.
# Actual Twi: Ɔkyena yɛ da foforɔ
#
# English: All days are not equal
# Predicted Twi: Ɛnsɛ sɛ nnɛ nnɛ nn
# Actual Twi: Mmerɛ nyinaa nsɛ
#
# English: I will see you soon
# Predicted Twi: M'ani n'ani n'ani so.
# Actual Twi: Mehu wo seesei ara
#
# English: Where do you come from?
# Predicted Twi: Where do wo kɔ?
# Actual Twi: Wo firi ɛhe fa?
#
# English: Do you like me?
# Predicted Twi: So wopɛ me?
# Actual Twi: W'ani gye me ho anaa?
#
# English: And they sent the students
# Predicted Twi: They tɔɔ n'abusua no.
# Actual Twi: Na wɔ somaa asukuufoɔ no
#
# English: I have received it
# Predicted Twi: Since me awie
# Actual Twi: Me nsa aka
#
# English: nobody is above anyone
# Predicted Twi: n'ani nnye n'abusua.
# Actual Twi: obiara nyɛ obiara
#
# English: you have the face of a goat
# Predicted Twi: Wɔre a ɔbarima no a ɔre a ɔ
# Actual Twi: wanim sɛ odwan
#
# English: I am doing very well
# Predicted Twi: M'ani gye a ɛsɛ sɛ meyɛ a
# Actual Twi: Me ho yɛ pa ara
#
# English: my love for you will never die
# Predicted Twi: Me n'ani gye wo n'ani n'ani n'
# Actual Twi: ɔdɔ a mewɔ ma wo no nni awieyɛ
#
# English: I’m feeling sleepy
# Predicted Twi: Me n’ani n’ani.
# Actual Twi: M’ani kum
#
# English: Get up
# Predicted Twi: sɛ u n'ani.
# Actual Twi: Sɔre
#
# English: Kofi is a womanizer.
# Predicted Twi: Kofi yɛ ɔbarima.
# Actual Twi: Kofi yɛ mmaasɛm.
#
# English: My father is a trader
# Predicted Twi: Me papa a trader a ɔrebɔ a
# Actual Twi: Me papa yɛ oguadini
#
# English: Welcome.
# Predicted Twi: Welcome
# Actual Twi: Akwaaba.
#
# English: Kwame is a male Saturday born
# Predicted Twi: Kwame a ɔbarima a ɔwɔ a ɔwɔ
# Actual Twi: Kwame yɛ din a yɛde frɛ mmarima a yɛwo wɔn Memeneda
#
# English: Thank you for this opportunity.
# Predicted Twi: Ɛnyɛ wo sɛ yɛn ayɛ a ns
# Actual Twi: Meda mo ase wɔ akwanya a, mo de ama me ho.
#
# English: Chief
# Predicted Twi: <extra_id_0>
# Actual Twi: ɔhene
#
# English: No
# Predicted Twi: <extra_id_0>
# Actual Twi: Daabi
#
# English: how is the family
# Predicted Twi: a n'abusua no?
# Actual Twi: abusuafoɔ ho te sɛn
#
# English: how was your journey?
# Predicted Twi: Would you describe w'adwuma?
# Actual Twi: ɛkwan so ɛ?
#
# English: have you eaten?
# Predicted Twi: a woae?
# Actual Twi: woadidi?
#
# English: sleep well
# Predicted Twi:
# Actual Twi: da yie
#
# English: dress up
# Predicted Twi:
# Actual Twi: siesie wo ho
#
# English: How are you?
# Predicted Twi: Ɛhe?
# Actual Twi: Wo ho te sɛn?
#
# English: good bye
# Predicted Twi: a yɛ nsɛm
# Actual Twi: nante yie
#
# English: i'm from Ghana
# Predicted Twi: i'm Ghana
# Actual Twi: mefiri Ghana
#
# English: I'm tourist
# Predicted Twi: M'ani a ɔhaw
# Actual Twi: meyɛ nsrahwɛni
#
# English: i work at the ministries
# Predicted Twi: i n'adwuma no a ɛwɔ nsrahw
# Actual Twi: meyɛ adwuma wɔ aban asuayɛ
#
# English: let's go to the market
# Predicted Twi: yɛnkɔ n'abusua a ɛtɔ so.
# Actual Twi: ma yɛnkɔ dwaso
#
# English: where are you going?
# Predicted Twi: Where do w'abusua?
# Actual Twi: worekɔ he?
#
# English: where are you?
# Predicted Twi: Where?
# Actual Twi: wowɔ  he?
#
# English: i'm hungry
# Predicted Twi: i'm hungry
# Actual Twi: ɔkɔm de me
#
# English: i hate you
# Predicted Twi: i n'abusua
# Actual Twi: metan wo
#
# English: it is raining
# Predicted Twi: sɛ n'abusua
# Actual Twi: nsuo retɔ
#
# English: evening time
# Predicted Twi: a <extra_id_1>
# Actual Twi: ade asa
#
# English: it's too expensive, i can offer 5 cedis
# Predicted Twi: ɛnyɛ ɔhaw a ɛwɔ ɔhaw a ɛwɔ
# Actual Twi: ne boɔ yɛ den, mɛma wo 5 cedis
#
# English: thank you too
# Predicted Twi:
# Actual Twi: me nso medaase
#
# English: turn the air-conditioner on
# Predicted Twi: -
# Actual Twi: sɔ air-conditioner no
#
# English: My wife
# Predicted Twi: Wife
# Actual Twi: Me yere
#
# English: Get up
# Predicted Twi: sɛ u n'ani.
# Actual Twi: Sɔre
#
# English: I am a pastor
# Predicted Twi: M'ani yɛ sɛ meyɛ
# Actual Twi: Meyɛ Ɔsofo
#
# English: We are heading to our next destination
# Predicted Twi: Wɔrekɔ a yɛn n'abusua no.
# Actual Twi: Sesei yɛrekɔ bea foforɔ so
#
# English: In thy light we see light.
# Predicted Twi: Ɛnyɛ n'ani a yɛn n'ani.
# Actual Twi: Wo hann mu na yɛhunu ɛhann.
#
# English: how much will you charge?
# Predicted Twi: Woulda wobea?
# Actual Twi: wobɛgye sɛn?
#
# English: okay please bring
# Predicted Twi: sɛ u n'abusua
# Actual Twi: yoo fa bra
#
# English: i wish to offer
# Predicted Twi: i pɛ sɛ me a sɛ me a
# Actual Twi: mepɛsɛ metua
#
# English: i cannot pay that much
# Predicted Twi: nnɛ sɛ i nnɛ nnɛ n
# Actual Twi: mentumi ntua saa
#
# English: what will be the fare
# Predicted Twi: sɛ a ɛsɛ sɛ a ɛsɛ
# Actual Twi: yɛbɛgye me sɛn
#
# English: I am from Ghana
# Predicted Twi: M'ani Ghana
# Actual Twi: Mefiri Ghana
#
# English: I am from Ghana
# Predicted Twi: M'ani Ghana
# Actual Twi: Mefiri Ghana
#
# English: Eye
# Predicted Twi: <extra_id_0>
# Actual Twi: Ani
#
# English: Come here now
# Predicted Twi: Ɛnyɛ akɔ
# Actual Twi: Bra ha seesei yi ara
#
# English: There
# Predicted Twi: <extra_id_0>
# Actual Twi: Ɛhɔ
#
# English: Go
# Predicted Twi: <extra_id_0>
# Actual Twi: Kɔ
#
# English: Queen
# Predicted Twi: <extra_id_0>
# Actual Twi: Ɔhemaa
#
# English: Love
# Predicted Twi: <extra_id_0>
# Actual Twi: Ɔdɔ
#
# English: Come here!
# Predicted Twi: Ɛnyɛ!
# Actual Twi: Bra ha!
#
# English: Is it time to eat?
# Predicted Twi: So ɛsɛ sɛ ɛsɛ sɛ ɛsɛ
# Actual Twi: mmerɛ aso sɛ yedidi?
#
# English: I'm looking for a bag for my wife.
# Predicted Twi: M'ani gye bag a me nneɛma a me n'
# Actual Twi: Merepɛ forotɔ akɔma me yere.
#
# English: What's your older sister's name?
# Predicted Twi: Ɛhe ne wo n'abusua no?
# Actual Twi: Wonuabaa panin din de sɛn?
#
# English: I have no idea where Asamoah is now.
# Predicted Twi: M'ani gye sɛnea Asamoah a ɔrekɔ
# Actual Twi: Mennim baabi a Asamoa wɔ seisei.
#
# English: Kwaku is a hero.
# Predicted Twi: Kwaku a ɔde a n'abusua.
# Actual Twi: Kwaku yɛ ɔkofo.
#
# English: I need an extra pillow.
# Predicted Twi: M'ani gye a sɛ mepɛ a sɛ me
# Actual Twi: Mehia summii baako aka ho.
#
# English: Do you have an umbrella that I could borrow?
# Predicted Twi: So woa nsu a mepɛ sɛ mebɔ?
# Actual Twi: Wowɔ kyineɛ a, metumi afɛm anaa?
#
# English: Nothing like that will happen again.
# Predicted Twi: Ɛnyɛ sɛ nnɛ a ɛbɛba a
# Actual Twi: Biribi saa rensi biom.
#
# English: I am looking forward to receiving your favorable answer.
# Predicted Twi: M'ani gye sɛ me n'ani gye wo sɛ
# Actual Twi: Merehwɛ animu sɛ menya mmuae pa afiri wo nkyɛn
#
# English: I don't want anybody to get hurt.
# Predicted Twi: M'ani pɛ sɛ obiara a ɔbɔ n'
# Actual Twi: Mempɛ sɛ obiara bepira.
#
# English: His father always comes home late.
# Predicted Twi: Ɔbaa no akɔ fie a ɔrekɔ fie.
# Actual Twi: Daa ne papa mma fie ntɛm.
#
# English: I don't think it'll rain this afternoon.
# Predicted Twi: M'ani gye sɛ ɛbɛboa awiei a
# Actual Twi: Mennye nni sɛ, nsuo bɛtɔ awia yi.
#
# English: Tell me a little about yourself.
# Predicted Twi: Ɛka kyerɛ me a ɛsɛ sɛ wo ne
# Actual Twi: Ka wo ho asɛm kakra kyerɛ me.
#
# English: I lost my job on Monday.
# Predicted Twi: M'ani n'adwuma no on Monday.
# Actual Twi: Dwoada na mehweree m'adwuma
#
# English: I've been asked to help you.
# Predicted Twi: M'ani awiei me sɛ meboa wo.
# Actual Twi: Yɛse memmɛ boa wo.
#
# English: He grew up in a small town.
# Predicted Twi: Ɔkɔɔ ɔdan a ɔwɔ ɔdan a ɔ
# Actual Twi: Kuro ketewaa mu na onyinii.
#
# English: It costs too much.
# Predicted Twi: Ɛno ara a ɛsɛ sɛ ɛsɛ
# Actual Twi: Neboɔ yɛ den dodo.
#
# English: You're too tall.
# Predicted Twi: W'ani gye.
# Actual Twi: Wo ware dodo
#
# English: You're too tall.
# Predicted Twi: W'ani gye.
# Actual Twi: Woyɛ tenten dodo
#
# English: She is trying to lose weight.
# Predicted Twi: Ɔrebɔ sɛ ɔbɛtɔ awie.
# Actual Twi: ɔrebɔ mmɔden sɛ ne so bɛte
#
# English: Have you been told when to come?
# Predicted Twi: So woakyerɛw sɛ wobɛba?
# Actual Twi: Wɔkyerɛɛ wo da a  ɛsɛsɛ wo ba?
#
# English: I have a week to do my homework.
# Predicted Twi: M'ani awie a ɛsɛ sɛ meyɛ me
# Actual Twi: Mewɔ nnawɔtwe sɛ mewie me fie adwuma.
#
# English: All these devices are unreliable.
# Predicted Twi: Ɛnyɛ nsɛm a ɛwɔ nsɛm
# Actual Twi: Mfa w'ani nto mfidie yi nyinaa so
#
# English: Kwaku didn't look happy to see me.
# Predicted Twi: Kwaku nnim me sɛ ɔbɛsɛe me.
# Actual Twi: Kwaku hunuu me no, n'ani annye
#
# English: They just want an excuse to fire you.
# Predicted Twi: They pɛ sɛ ɔbɛbɔ wo.
# Actual Twi: Wɔrepɛ akwannya bi de ayi woadi.
#
# English: Frankly speaking, I don't agree with you.
# Predicted Twi: M'ani gye wo.
# Actual Twi: Nokwarenie, me ne wo nyɛ adwene.
#
# English: Kwaku eats like a pig.
# Predicted Twi: Kwaku sɔre a n'abusua.
# Actual Twi: Kwaku didi sɛ preko.
#
# English: He is a man of noble birth.
# Predicted Twi: Ɔyɛ ɔbarima a ɔyɛ ɔbarima a
# Actual Twi: ɔyɛ dehyeɛ
#
# English: You aren't allowed to go into that room.
# Predicted Twi: Wɔmfa n'adwene sɛ wokɔ saa nsu
# Actual Twi: Wonni ho kwan sɛ wokɔ saa dan no mu.
#
# English: Kwaku said that he was feeling tired.
# Predicted Twi: Kwaku kae sɛ ɔyɛ n'ani a ɔre
# Actual Twi: Kwaku kaa sɛ, w'aberɛ.
#
# English: Kwaku and Abena bought a house in Boston last year.
# Predicted Twi: Kwaku ne Abena tɔɔ ahome wɔ Boston mu a
# Actual Twi: Kwaku ne Abena tɔɔ efie wɔ Boston afe a ɛtwa mu no
#
# English: The scar on his cheek hardly shows now.
# Predicted Twi: Ɔbɔɔ no a ɔrebɔ no a ɔre
# Actual Twi: Worenhyɛda nhunu kotwa a ɛda nemfono so no seisei
#
# English: She stood on her head.
# Predicted Twi: Ɔbɔɔ ne n'abusua.
# Actual Twi: Ogyinaa ne ti so
#
# English: They're coming for us.
# Predicted Twi: They coming for us.
# Actual Twi: Wɔreba abɛfa yɛn.
#
# English: I thought it was a mistake to tell Kwaku the secret.
# Predicted Twi: Ná misusuw sɛ ɛyɛ ayɛ a ɛyɛ
# Actual Twi: Na mefiri sɛ, ɛyɛ mfomsoɔ sɛ mɛda asumasɛm no adi akyerɛ Kwaku.
#
# English: The newspaper said that a typhoon was approaching.
# Predicted Twi: Ɔmanpanin no kae sɛ a nnipa a
# Actual Twi: Dawubɔ krataa no kaa sɛ, mframa gyamfantrudu bi rebobɔba.
#
# English: I want to see Kwaku now.
# Predicted Twi: Mepɛ sɛ me see Kwaku a ɛsɛ.
# Actual Twi: Mepɛ sɛ mihunu Kwaku seisei yi ara.
#
# English: Kwaku will be here on Monday.
# Predicted Twi: Kwaku bɛkɔ ɔhaw a ɛtɔ so.
# Actual Twi: Kwaku bɛba ha Dwoada.
#
# English: They started kissing each other.
# Predicted Twi: They went asleep.
# Actual Twi: Wɔhyɛɛ ase fee wɔn ano.
#
# English: Kwaku is the person who helped Abena.
# Predicted Twi: Kwaku yɛ ɔbarima a ɔde Abena awie
# Actual Twi: Kwaku na ɔboaa Abena.
#
# English: Tell her that I know who she is.
# Predicted Twi: M'ani gye no sɛ me ne nea ɔyɛ.
# Actual Twi: Kakyerɛ no sɛ menim nipa ko a, ɔyɛ.
#
# English: You are home late.
# Predicted Twi: Woree a few weeks.
# Actual Twi: Woamma fie ntɛm.
#
# English: He felt a sudden urge to write a novel.
# Predicted Twi: Ɔtee sɛ ɔbɛyɛ a ɔde n'
# Actual Twi: Onyaa atinka prɛkopɛ sɛ ɔbɛtwerɛ nnwoma.
#
# English: I'm defenseless.
# Predicted Twi: M'ani gye me.
# Actual Twi: Menni ɔgyefoɔ biara.
#
# English: Louder, please.
# Predicted Twi: Please, sɛ a sɛ u n'ani a
# Actual Twi: Mepa wo kyew, ma wo nne so
#
# English: I thought Kwaku needed help.
# Predicted Twi: Ná misusuw sɛ Kwaku n'ani n'ani.
# Actual Twi: Na mefiri sɛ, Kwaku hia mmoa.
#
# English: I will come with you.
# Predicted Twi: M'ani bɛba wo.
# Actual Twi: Me ne wo bɛkɔ
#
# English: At 10 o'clock yesterday, there were hundreds of people outside.
# Predicted Twi: Ɔkwan a ɛtɔ nnɔpa a ɛ
# Actual Twi: Nnɔn du bɔe no, na nnipa ɔha ne akyire na wɔwɔ abɔnten so.
#
# English: Thank you for clearing up the misunderstanding.
# Predicted Twi: Ɛnyɛ wo sɛ wobɛka nsɛm no a
# Actual Twi: Meda wo ase s woakyerɛkyerɛ nsɛm no mu.
#
# English: Some people think eating at home is better for you than eating out.
# Predicted Twi: Ɛnyɛ nnipa a wɔde akɔ fie sɛ wo
# Actual Twi: Ebinom adwen ne sɛ, efie adidie yɛ kyɛn abɔntensodeɛ.
#
# English: He likes cooking for his family.
# Predicted Twi: Ɔpɛ sɛ ɔpɛ sɛ ɔpɛ
# Actual Twi: ɔtae noa aduane ma n'abusuafoɔ.
#
# English: Give me a hint.
# Predicted Twi: Please, sɛ me n'ani a n'ani a
# Actual Twi: Ti ho kyerɛ me
#
# English: It isn't much of a car.
# Predicted Twi: Ɛnyɛ kar.
# Actual Twi: ɛnyɛ ɛhyɛn papa biara.
#
# English: The dog's collar is red.
# Predicted Twi: Ɔman no collar no gray.
# Actual Twi: ɔkraman no ahusuo yɛ kɔkɔɔ.
#
# English: I often listen to sad songs.
# Predicted Twi: M'ani n'ani n'ani n'ani n'ani
# Actual Twi: Metaa tie awerɛho nnwom.
#
# English: What am I gonna tell Kwaku?
# Predicted Twi: Ɛhe na meka Kwaku?
# Actual Twi: ɛdeɛn na merekɔka akyerɛ Kwaku?
#
# English: Yes. You're absolutely right.
# Predicted Twi: Yɛsɛ sɛ woyɛ a ɛsɛ sɛ wo
# Actual Twi: Ampa. Wo di bim.
#
# English: Kwaku doesn't know about those kinds of things.
# Predicted Twi: Kwaku nnim nsɛm a ɛyɛ saa n
# Actual Twi: Kwaku nnim hwee fa saa nneɛma no ho
#
# English: Kwaku decided to drop out of school and work full-time.
# Predicted Twi: Kwaku sɛ ɔkɔ sukuu akɔ sukuu no, na
# Actual Twi: Kwaku yɛɛn'adwene sɛ, ɔbɛgyae sukuu na wayɛ adwuma nko ara.
#
# English: I'll call for you at 8 tomorrow morning.
# Predicted Twi: Mɛbɛbɔ wo nnɔpa a ɛtɔ ɔ
# Actual Twi: Mɛsoma ama woaferɛ wo ɔkyena anɔpa nɔn wɔtwe.
#
# English: That's what people say.
# Predicted Twi: Ɛno ne sɛ nkurɔfo ka.
# Actual Twi: Sa ara na wɔrekeka.
#
# English: I like swimming, but I don't like to swim here.
# Predicted Twi: M'ani gye sɛ mekɔ hɔ, nanso mepɛ
# Actual Twi: Mepɛ nsuom adwareɛ, nanso mempɛ sɛ mɛdware wɔha.
#
# English: Choose any one from among these.
# Predicted Twi: Ɛnyɛ n'ani gye a ɛwɔ n'ani
# Actual Twi: Hwehwɛ mu na yi baako.
#
# English: Why should I believe that?
# Predicted Twi: Ɛnsɛ sɛ me n'ani nnye saa?
# Actual Twi: Deɛn nti a, ɛwɔ sɛ megye saa edi?
#
# English: We are sorry we are unable to accept your request.
# Predicted Twi: Wɔhyɛ sɛ yɛn ntumi ntumi ntumi
# Actual Twi: Yɛntumi nnye w'abisadeɛ no ntom, fa kyɛ yɛn.
#
# English: Do you really love me?
# Predicted Twi: So wopɛ me?
# Actual Twi: Wo dɔ me ampa ara?
#
# English: Don't risk your neck over something foolish.
# Predicted Twi: Ɛnyɛ sɛ wo n'ani nnye n'as
# Actual Twi: Nha wo ho wɔ nsɛm a, ɛho nhia ho.
#
# English: What time do you want me to pick you up?
# Predicted Twi: Would you want me sɛ me n'ani akɔ?
# Actual Twi: Mmere bɛn na wo pɛ sɛ mebɛfa wo?
#
# English: Would you like some chocolate ice cream?
# Predicted Twi: Would w'adwene sɛ wopɛ ice cream?
# Actual Twi: So wobɛpɛ ice cream a  ɛwɔ chocolate bi?
#
# English: I'm never going to get married.
# Predicted Twi: M'ani nnye sɛ me n'ani nnye.
# Actual Twi: Merenware dabiara da.
#
# English: Kwaku's grandfather and Abena's grandfather fought together in World War II.
# Predicted Twi: Kwaku ne Abena n'abusua no n'abus
# Actual Twi: Kwaku ne Abena nena koo wo wiase afaamu ɔsa a na ɛto so mmienu no mu
#
# English: Kwaku can't ski.
# Predicted Twi: Kwaku nnɔ.
# Actual Twi: Kwaku ntumi ny
#
# English: He has a Japanese car.
# Predicted Twi: Ɔwɔ Japan car.
# Actual Twi: ɔwɔ Japanfoɔ hyɛn.
#
# English: I did this for you.
# Predicted Twi: Me didi saa ayɛ.
# Actual Twi: Meyɛɛ wei de maa wo.
#
# English: Kwaku doesn't want to get involved.
# Predicted Twi: Kwaku n'ani pɛ sɛ ɔbɛba akɔ.
# Actual Twi: Kwaku mpɛ sɛ, ɔde ne ho bɛfɔrefɔre mu.
#
# English: I heard a dog barking in the distance.
# Predicted Twi: M'ani n'ani kyerɛw a n'aky
# Actual Twi: Metee sɛ na ɔkraman bi repo wɔ akyire.
#
# English: My parents are English, but they came to Brazil in 2001.
# Predicted Twi: Me papa no yɛ Engiresi, nanso wɔkɔɔ Brazil a ɛ
# Actual Twi: M'awofo yɛ Enyiresifo, nanso wɔbaa Brazil afe 2001
#
# English: Kwaku is dreaming.
# Predicted Twi: Kwaku snrow.
# Actual Twi: Kwaku reso daeɛ.
#
# English: Today is my sixteenth birthday.
# Predicted Twi: Ɛnnɛ sɛ me n'abusua a
# Actual Twi: ɛnnɛ yɛ m'awoda a ɛtɔso dunsia.
#
# English: The noise gets on my nerves.
# Predicted Twi: Ɛnsɛ sɛ n'ani awie no.
# Actual Twi: Dede no tuatua m'aso.
#
# English: If you go anywhere, you had better tell your mother first.
# Predicted Twi: Sɛ wokɔ biribi a, ɛsɛ sɛ wobɛka
# Actual Twi: Baabiara a wobɛkɔ no, ɛwɔ sɛ wobɔ wo maame amaneɛ ansa
#
# English: He carved a Buddhist image out of wood.
# Predicted Twi: Ɔde n'akyi a ɔde n'aky
# Actual Twi: ɔde dua no nwenee Budhafoɔ mfoni.
#
# English: Many foreign language students dream of speaking like a native.
# Predicted Twi: Ɛnyɛ nnipa a wɔde n'adwuma a
# Actual Twi: Adesuafo bebree a wosua kasa ahorow no, so daeɛ sɛ wɔbetumi aka kasa no sɛ wɔn kurom kasa
#
# English: She can play the violin, not to mention the piano.
# Predicted Twi: Ɔsɛ sɛ ɔbɛbɔ n'akyi,
# Actual Twi: Otumi bɔ nsakuo tesɛ violin, na piano koraa deɛ yɛnka
#
# English: I don't know who to ask for advice.
# Predicted Twi: M'ani gye n'ani sɛ mepɛ sɛ me
# Actual Twi: Mennim obiara a merekɔgye afutuo afiri ne nkyɛn.
#
# English: I like listening to NPR.
# Predicted Twi: M'ani gye NPR.
# Actual Twi: Me taa tie NPR.
#
# English: His story amused everyone.
# Predicted Twi: Ɔkyerɛkyerɛkyerɛkyerɛ no awie.
# Actual Twi: N'asɛm no yɛɛ obi biara sere.
#
# English: They're walking without shoes.
# Predicted Twi: They n'abusua.
# Actual Twi: Wɔnam a wɔnhyɛ mpaboa
#
# English: The newspaper had very good pictures.
# Predicted Twi: Ɔkyerɛkyerɛfo no ayɛ nsɛm
# Actual Twi: Mfoni a ɛwɔ dawurubɔ krataa no mu yɛ fɛ pa ara.
#
# English: Kwaku doesn't want to go there.
# Predicted Twi: Kwaku n'ani pɛ sɛ ɔkɔ hɔ.
# Actual Twi: Kwaku mpɛ sɛ ɔbɛkɔ hɔ.
#
# English: They are demanding shorter working hours.
# Predicted Twi: They abɛpɛ sɛ wɔde ayɛ adwuma.
# Actual Twi: Wɔrebisa sɛ wɔbɛyɛ adwuma nnɔnhwere tiawa
#
# English: I know where to hide.
# Predicted Twi: M'ani gye n'abusua.
# Actual Twi: Menim baabi a mesie.
#
# English: You can't give up.
# Predicted Twi: Wɔsrɛ wo sɛ wobɛfa.
# Actual Twi: ɛmpaaba.
#
# English: These shoes are too small.
# Predicted Twi: These sandals no yɛ n'ani.
# Actual Twi: Saa mpaboa no sua dodo.
#
# English: I love GhanaNLP
# Predicted Twi: GhanaNLP
# Actual Twi: Medɔ GhanaNLP
#
# English: Ghana is a lovely place
# Predicted Twi: Ghana a ɔhaw a ɛyɛ Ghana.
# Actual Twi: Ghana yɛ baabi a ɛyɛ dɛ yie
#
# English: Lets do this together
# Predicted Twi: Ɛsɛ sɛ yɛyɛ eyi yɛn.
# Actual Twi: Yɛnyɛ wei mmom
#
# English: Let's take care of ourselves
# Predicted Twi: Ɛsɛ sɛ yɛnyɛ yɛn ho yɛn ho
# Actual Twi: Yɛnhwɛ yɛn ho so yie
#
# English: Together , let's build the nation
# Predicted Twi: Together, sɛ yɛn n'adwuma a
# Actual Twi: Ma yɛnhyehyɛ ɔman no mmom
#
# English: Are you coming today
# Predicted Twi: Ɛnyɛ wo a n'ani?
# Actual Twi: Woreba nnɛ?
#
# English: Add more data below and test it
# Predicted Twi: Ɛnyɛ nsɛm a ɛsɛ sɛ
# Actual Twi: Fa nsɛm bebree ka hoo wo aseɛ ha na sɔhwɛ
#
# English: This is a book.
# Predicted Twi: Ɛyɛ a sɛ ɛyɛ a sɛ ɛyɛ
# Actual Twi: Wei yɛ nwoma
#
# English: This is not a book.
# Predicted Twi: Ɛnyɛ nsɛm.
# Actual Twi: Wei nyɛ nwoma
#
# English: Is this a book?
# Predicted Twi: So these a nsɛm?
# Actual Twi: Wei yɛ nwoma anaa?
#
# English: What is it?
# Predicted Twi: Ɛyɛ?
# Actual Twi: ɛyɛ deɛn?
#
# English: That is a pencil.
# Predicted Twi: Ɛno yɛ pencil.
# Actual Twi: ɛno yɛ twerɛdua
#
# English: That is not a pencil.
# Predicted Twi: Ɛnyɛ pencil.
# Actual Twi: ɛno nyɛ twerɛdua
#
# English: The firemen battered down the door.
# Predicted Twi: They n'abusua no tɔɔ no.
# Actual Twi: Odumgyafoo no bubuu epono no
#
# English: Akosua is happier now.
# Predicted Twi: Ná Akosua n'ani n'ani n'ani.
# Actual Twi: Akosua ani agye seisei
#
# English: It's not a watch.
# Predicted Twi: Ɛnyɛ n'adwuma.
# Actual Twi: ɛnyɛ watch
#
# English: Let's check the map.
# Predicted Twi: Ɛnyɛ sɛ yɛn nsɛm no.
# Actual Twi: Yɛnhwɛ map no
#
# English: Did you notice any change?
# Predicted Twi: So woakyerɛw a n'adwuma no?
# Actual Twi: Wohunuu nsonsoeɛ bi anaa?
#
# English: Akosua smiled at the waitress.
# Predicted Twi: Akosua snɛɛ ɔbarima no.
# Actual Twi: Akosua sere hwɛɛ ahɔhohwɛ nii no
#
# English: Kwabena can't refuse his grandchildren anything.
# Predicted Twi: Kwabena nnɛ sɛ ɔbɛka ne nnamfo
# Actual Twi: Kwabena ntumi nfa hwee nkame ne nananom
#
# English: Do you want to be a bartender all your life?
# Predicted Twi: So w'ani pɛ sɛ wubedi bartender a w'a
# Actual Twi: Wopɛ sɛ wohwɛ ahɔhoɔ wɔ nsanom bea wo nkwa nna nyinaa?
#
# English: Every day Adwoa took baskets full of bread to the poor and cared for the sick.
# Predicted Twi: Ɔda biara a Adwoa tɔɔ nsɛm
# Actual Twi: Dabiara na Adwoa fa paano kɛntɛn mma de kɔma ahiafoɔ na ɔsan hwɛ ayarefoɔ
#
# English: Kwabena destroyed the children's sand castle.
# Predicted Twi: Kwabena destroyed a nnipa a wɔde awiei
# Actual Twi: Kwabena sɛe mmɔfra no anwia ahenfo dan no
#
# English: It's already 7 o'clock.
# ...
# Actual Twi: Megyedi sɛ Abena yam hyew no
#
# English: It's my turn to wash the dishes.
# Predicted Twi: Ɛyɛ me sɛ me n'ani bɛtɔ n'
# Actual Twi: Aduru me so sɛ metwitwi nkukuw no mu
#
# English: There was blood all over the floor.
# Predicted Twi: Ɔsram no awiei.
# Actual Twi: Na mogya asane afa fam hɔ nyinaa
#
# English: I'm here to learn French.
# Predicted Twi: M'ani n'ani kɔ so sɛ mekɔ Franse.
# Actual Twi: Mewɔ ha sɛ merebesua French
#
# English: I cannot praise you enough.
# Predicted Twi: M'ani nnye wo sɛ mepɛ sɛ mepɛ
# Actual Twi: Mentumi nnyae wo nsammranebɔ
#
# English: First come, first served.
# Predicted Twi: Ɔbaa no, ɔbaa no.
# Actual Twi: Agoru bɛsɔ a efiri anɔpa
#
# English: The boy tried to be a man and not cry.
# Predicted Twi: Ɔbaa no sɛ ɔyɛ n'ani a ɔ
# Actual Twi: Abaamuwaa  no bɔɔ ne ho mmɔden sɛ ɔrensu
#
# English: I never give up.
# Predicted Twi: M'ani n'ani.
# Actual Twi: Memma me nsa so dabiara da.
#
# English: Kwame missed his wife and their children.
# Predicted Twi: Kwame n'abusua ne ne nnamfo ne ne nnamfo
# Actual Twi: Kwame fee ne yere ne ne mma no.
#
# English: I had rented it the day before.
# Predicted Twi: M'ani awiei no a ɛtɔ no.
# Actual Twi: Na mahae no nnera deda.
#
# English: Do you want to stop Kwame?
# Predicted Twi: So wopɛ sɛ wopɛ sɛ wopɛ sɛ
# Actual Twi: Wopɛ sɛ wotumi ma Kwame gyae nea reyɛ no?
#
# English: How old is this piano?
# Predicted Twi: Ɔhow a ɛyɛ a ɛyɛ?
# Actual Twi: Piano senkuo no adi mfie sɛn?
#
# English: I'm practically already an adult.
# Predicted Twi: M'ani gye sɛ meyɛ a yɛn a yɛ
# Actual Twi: Manyini awie ara nen
#
# English: I'm content with my job.
# Predicted Twi: M'ani gye me n'adwuma.
# Actual Twi: M'ani gye m'adwuma no ho.
#
# English: He had to stay in bed.
# Predicted Twi: Ɔsɛ sɛ ɔkɔ bed.
# Actual Twi: Na ɛsɛ sɛ ɔka mpa mu.
#
# English: That's what I thought you said.
# Predicted Twi: Ɛnyɛ nea mepɛ sɛ wokae.
# Actual Twi: Medwen sɛ saa na wokae
#
# English: Play another song for us.
# Predicted Twi: Ɛnyɛ n'ani a yɛde n'ani a
# Actual Twi: Bɔ nnwom foforow ma yɛn
#
# English: What is it called?
# Predicted Twi: Ɛyɛ nea ɛbɛyɛ?
# Actual Twi: Yɛfrɛ no sɛn?
#
# English: It seems that Kwame might win.
# Predicted Twi: Ɛte saa sɛ Kwame awie.
# Actual Twi: Asɛ Kwame bedi nkunim.
#
# English: Kwame persuaded Adwoa to help John.
# Predicted Twi: Kwame awiei Adwoa sɛ ɔbɛboa John.
# Actual Twi: Kwame ne Adwoa kasae ma ɔgye toomu sɛ ɔbɛboa John.
#
# English: Kwame comes to school by bus and train.
# Predicted Twi: Kwame kɔ sukuu a ɔrekɔ ɔdan no.
# Actual Twi: Kwame fa ɛhyɛn ne keteke na ɛba sukuu.
#
# English: We should be fine.
# Predicted Twi: Ɛsɛ sɛ yɛn nkɔ.
# Actual Twi: Yɛn ho bɛyɛ
#
# English: Kwame and Adwoa were good friends.
# Predicted Twi: Kwame ne Adwoa yɛ nnamfo.
# Actual Twi: Na Kwame ne Adwoa yɛ nnamfo pa ara.
#
# English: What's it going to take to persuade you?
# Predicted Twi: Ɛbɛyɛ a ɛbɛyɛ a wobɛka sɛ wo
# Actual Twi: Deɛn na ɛbɛma woagye ato mu?
#
# English: Say it in French.
# Predicted Twi: Ɛyɛ Franse.
# Actual Twi: Ka wɔ French kasa mu.
#
# English: Kwame, this is my cousin.
# Predicted Twi: Kwame, yɛ me n'abusua.
# Actual Twi: Kwame, me nua ni.
#
# English: They set the time and place of the wedding.
# Predicted Twi: They kyerɛɛɛ ɔhaw no ne ɔhaw no.
# Actual Twi: Wɔahyɛ mmere ne faako a wɔbɛgye aware no.
#
# English: Someone rang the doorbell.
# Predicted Twi: Ɔbɔɔ a row no.
# Actual Twi: Obi miaa pono no abɛn so
#
# English: Everyone knew that.
# Predicted Twi: Everyone knew sɛ n'ani knew.
# Actual Twi: Na obiara nim.
#
# English: Why do you keep giving him money?
# Predicted Twi: Wususuw sɛ wo n'ani ayɛ sika?
# Actual Twi: Adɛn na wokɔ so ma no sika?
#
# English: Kwame's clothes are out of fashion.
# Predicted Twi: Kwame n'abusua no yɛ ɔhaw.
# Actual Twi: Kwame ntaade no atwamu.
#
# English: It all makes sense now.
# Predicted Twi: Ɛno ara yɛ n'ani.
# Actual Twi: Afei na mate ase yiye.
#
# English: They got married on Christmas Eve.
# Predicted Twi: They went on Christmas Eve.
# Actual Twi: Wɔwaree anwumere a edi bronya da anim no.
#
# English: I thought you'd stopped dating Kwame.
# Predicted Twi: Mepɛ sɛ wobɛba Kwame.
# Actual Twi: Na medwene sɛ wo ne Kwame nni hɔ biom.
#
# English: She has a habit of biting her nails.
# Predicted Twi: Ɔbɔ n'abusua a ɔde n'
# Actual Twi: Ɛyaa ɔkeka ne mmɔwerew.
#
# English: Kwame would never hurt you.
# Predicted Twi: Kwame n'ani nnye wo.
# Actual Twi: Kwame remma wunni yaw da.
#
# English: The baby started to cry.
# Predicted Twi: Ɔbaa no n'ani n'ani.
# Actual Twi: Abofra no hyɛɛ ase sui.
#
# English: Kwame was lying on the bed.
# Predicted Twi: Kwame n'abusua no.
# Actual Twi: Kwame daa mpa no so.
#
# English: Go with these men.
# Predicted Twi: Please, sɛ yɛn nkurɔfo no.
# Actual Twi: Ɛne mmerante yi nkɔ
#
# English: A fish leaped out of the water.
# Predicted Twi: Ɔbarima a ɔde akɔ akɔ no mu.
# Actual Twi: Mpataa bi yii ne ti firii nsu no mu.
#
# English: I spent 3,000 yen on a new CD.
# Predicted Twi: M'ani sika sika sika a ɛwɔ CD no.
# Actual Twi: Mebɔɔ ka apem aha miɛnsa wɔ CD yi ho.
#
# English: Kwame is coming over this evening.
# Predicted Twi: Kwame akɔ awiei a ɛtɔ so.
# Actual Twi: Kwame bɛba ha anwumere yi.
#
# English: Did you ever hear the like of it?
# Predicted Twi: So woakyerɛw sɛ ɛyɛ a ɛyɛ?
# Actual Twi: Wate bi da?
#
# English: Adwoa and Pokua value their privacy.
# Predicted Twi: Adwoa ne Pokua n'ani n'ani n'ani
# Actual Twi: Adwoa ne Pokua pɛ wɔn tirimuka
#
# English: I remember seeing him once.
# Predicted Twi: Ɔbɔɔ me n'ani a ɔrehu no.
# Actual Twi: Mekae sɛ mɛhunu no da
#
# English: We came to the conclusion that we should support the movement.
# Predicted Twi: Ɛno ara yɛn nsɛm sɛ yɛn
# Actual Twi: Yɛbɛtee ase sɛ ɛsɛ sɛ yɛboa dwumadie no.
#
# English: There are large houses along the street.
# Predicted Twi: Ɛwɔ nnipa a wɔde awie no mu.
# Actual Twi: Mfie akɛse wɔ kwan no ho
#
# English: He has a Picasso.
# Predicted Twi: Picasso.
# Actual Twi: Ͻwɔ Picasso
#
# English: Pokua is still looking for Adwoa.
# Predicted Twi: Pokua n'ani n'ani sɛ ɔbɛhweh
# Actual Twi: Pokua gu so rehwehwɛ Abena
#
# English: Pokua looked toward Adwoa.
# Predicted Twi: Pokua swired Adwoa.
# Actual Twi: Pokua hwɛɛ Abena anim
#
# English: She lives in Yokohama.
# Predicted Twi: Ɔkɔɔ Yokohama.
# Actual Twi: Ͻte Yokohama
#
# English: Choose between these two.
# Predicted Twi: Ɛnyɛ n'adwuma a ɛwɔ n'a
# Actual Twi: Yi nneɛma abien yi mu baako
#
# English: That isn't a good reason.
# Predicted Twi: Ɛnyɛ sɛ ɛnyɛ a ɛyɛ a ɛ
# Actual Twi: Botae no ntɔ asom.
#
# English: Pokua must consider carefully whether he really wants a divorce or not.
# Predicted Twi: Ɛsɛ sɛ ɔpɛ sɛ ɔpɛ
# Actual Twi: Ɛsɛ sɛ Pokua dwene awaregyae no ho yiye
#
# English: We want our money back.
# Predicted Twi: Wɔpɛ sɛ yɛn sika bɛkɔ.
# Actual Twi: Fa yɛn sika ma yɛn biom.
#
# English: Is everything you own in that chest?
# Predicted Twi: So ɛno nea wopɛ akɔ so?
# Actual Twi: Wo nneɛma nyinaa wɔ saa adaka no mu?
#
# English: In the future, try to get to the office on time.
# Predicted Twi: Ɛnnɛ, sɛ ɔbɛkɔ apolisifo no
# Actual Twi: Efiri nnɛ rekɔ, ɛyaa bɔ mmɔden sɛ wobɛba adwuma ntɛm
#
# English: Pokua didn't mean to offend Adwoa.
# Predicted Twi: Pokua nnim sɛ ɔbɔ Adwoa.
# Actual Twi: Na ɛnyɛ Pokua adwene sɛ ɔbɛfom Adwoa
#
# English: I'm afraid it's not going to be that easy.
# Predicted Twi: M'ani gye sɛ ɛbɛyɛ a ɛbɛyɛ
# Actual Twi: Mennyenni sɛ ɛbɛyɛ mmerɛ saa.
#
# English: This knife is dull.
# Predicted Twi: Ɛnyɛ sɛ n'ani a n'ani a
# Actual Twi: Sekan n'ano nyɛ nam.
#
# English: May I have the check, please?
# Predicted Twi: So me n'ani awie no, sɛ mewɔ?
# Actual Twi: Mepa wo kyɛw metumi anya me bo
#
# English: Pokua did it very carefully.
# Predicted Twi: Pokua did it a ɛyɛ den.
# Actual Twi: Pokua too ne boase yiye na ɔyɛe
#
# English: Pokua is going to survive.
# Predicted Twi: Ɛnyɛ sɛ Pokua bɛfa.
# Actual Twi: Pokuaa ho bɛtɔ no/befiri mu
#
# English: Pokua is getting married Pokuaorrow.
# Predicted Twi: Ɔkaa Pokua a ɔrebɔ Pokuaorrow.
# Actual Twi: Pokuaa reware kyena
#
# English: Yaw said he was too tired to dance.
# Predicted Twi: Yɛkyerɛɛ Yaw sɛ ɔyɛ sɛ ɔ
# Actual Twi: Yaw kaa sɛ wabrɛ dodo nti ɔrentumi nsa
#
# English: Yaw is disturbing Adwoa.
# Predicted Twi: Yɛsrɛ Adwoa.
# Actual Twi: Yaw reha Adwoa
#
# English: Yaw is an adult.
# Predicted Twi: Yɛyɛ a yɛn a yɛn ayɛ.
# Actual Twi: Yaw yɛ panyin
#
# English: That's quite a problem.
# Predicted Twi: Ɛyɛ a n'ani gye.
# Actual Twi: Ɛyɛ ɔhaw kakra
#
# English: I've told you not to call me Yaw.
# Predicted Twi: Meka kyerɛ wo sɛ wobɛba me Yaw.
# Actual Twi: Maka makyerɛ wo sɛ mfrɛ me Yaw
#
# English: I don't expect you to reply.
# Predicted Twi: Mepɛ sɛ wo n'ani nnye.
# Actual Twi: Mannwene sɛ wobɛma me mmuae
#
# English: Where's your key?
# Predicted Twi: Where a wo keys?
# Actual Twi: Wo safoa wɔ he?
#
# English: We stayed at a cheap hotel.
# Predicted Twi: Wɔde a ɔhaw a ɔwɔ a ɔwɔ
# Actual Twi: Yɛtraa ahɔhodan bi a ne bo nyɛ den mu.
#
# English: Could you bring me a blanket?
# Predicted Twi: So wobɛbɔ me a blanket?
# Actual Twi: Wobetumi abrɛ me kuntu?
#
# English: Yaw can barely breathe.
# Predicted Twi: Yɛsrɛ sɛ Yaw n'ani nnye.
# Actual Twi: Yaw home nsisi so yiye
#
# English: I want those back when you're done.
# Predicted Twi: Mepɛ sɛ woayɛ a ɛsɛ sɛ wo
# Actual Twi: Wowie a fabrɛ me
#
# English: Yaw is merely stating the obvious.
# Predicted Twi: Yɛrebɔ no sɛ ɔrebɔ no a ɛ
# Actual Twi: Yaw reka asem no sɛnea ɛte pɛpɛɛpɛ/ada adi
#
# English: I don't know what happened to Yaw.
# Predicted Twi: Me nnim nea a ɛtee no so.
# Actual Twi: Deɛn na ɛyɛɛ/ɛtoo Yaw?
#
# English: We went to the museum.
# Predicted Twi: Ɔkɔɔ museums.
# Actual Twi: Yɛkɔɔ tete nneɛma akorae hɔ.
#
# English: Do you want to look into it?
# Predicted Twi: So wopɛ sɛ wopɛ sɛ wopɛ sɛ
# Actual Twi: Wopɛ sɛ wohwehwɛ asɛm no mu ?
#
# English: I'm not taking any chances.
# Predicted Twi: M'ani nnye n'adwuma.
# Actual Twi: Mɛyɛ birbiara/ Memma m'ani mpa biribiara a ehia so.
#
# English: Tell Yaw to wait a moment.
# Predicted Twi: Ɛka kyerɛ Yaw sɛ ɔbɛhyɛ a
# Actual Twi: Ka kyerɛ Yaw sɛ ɔntwɛn
#
# English: You can't do this.
# Predicted Twi: Wuntumi nnye eyi.
# Actual Twi: Wontumi nyɛ sei/yei
#
# English: I'm being fired because I've been late to work a lot.
# Predicted Twi: M'ani gye me sɛ meyɛ adwuma a ɛwɔ
# Actual Twi: Wɔreyi m'adi  firi sɛ na mentae mma adwuma ntɛm
#
# English: I think what you need now is to eat something.
# Predicted Twi: Mepɛ sɛ wobɛyɛ ayɛ a ɛsɛ
# Actual Twi: Medwene sɛ nea ɛsɛ sɛ woyɛ  seesei nesɛ wudi biribi
#
# English: She died at the age of 54.
# Predicted Twi: Ɔde awiei a ɔwɔ 54.
# Actual Twi: Owui no na wadi mfie aduonum nnan
#
# English: We can handle that.
# Predicted Twi: Ɛnyɛ sɛ yɛn nkurɔfo.
# Actual Twi: Yebetumi ayɛ
#
# English: My head still hurts.
# Predicted Twi: Me n'ani n'ani.
# Actual Twi: Meti gu so yɛ me yaw
#
# English: I'm in the same boat.
# Predicted Twi: M'ani akɔ apontow no.
# Actual Twi: Saa haw no bi ara na mewɔ mu/ Saa asɛm no bi ara na m'ani tua
#
# English: Yaw showed her the letter from Santa Claus.
# Predicted Twi: Yɛkyerɛɛ no sɛ Santa Claus no akɔ no.
# Actual Twi: Yaw de krataa a efi Santa Claus no kyerɛɛ me
#
# English: We're pretty proud of ourselves.
# Predicted Twi: Ɛyɛ yɛn sɛ yɛn yɛn ho yɛn
# Actual Twi: Yɛbɔ yɛn ho sonkahyire
#
# English: It was pure chaos.
# Predicted Twi: Ɛyɛɛ nsɛm.
# Actual Twi: Na ɛyɛ basabasayɛ nko ara
#
# English: He is known to all the people in the town.
# Predicted Twi: Ɔyɛ n'adwuma no mu a ɔwɔ ɔman
# Actual Twi: Obiara nim no wɔ kurom hɔ
#
# English: I didn't ask Yaw to go there.
# Predicted Twi: M'ani nnim Yaw sɛ ɔkɔ hɔ.
# Actual Twi: Manka ankyerɛ Yaw sɛ ɔnkɔ hɔ
#
# English: Yaw is an evil man.
# Predicted Twi: Yɛyɛ n'ani gye.
# Actual Twi: Yaw yɛ nipa bɔne ni/ Yaw tirim wɔ sum.
#
# English: Jealousy was the motive for the murder.
# Predicted Twi: Ɛno ne sɛ n'adwuma no yɛ akɔ
# Actual Twi: Anibere ne botae a na ɛtaa okum n'akyi.
#
# English: The plants must have died because no one watered them.
# Predicted Twi: Ɛsɛ sɛ nnipa a ɔde n'a
# Actual Twi: Ɛbɛyɛ sɛ afifide no wuwui efisɛ obiara amma so nsu.
#
# English: Yaw doesn't even remember what happened last night.
# Predicted Twi: Yɛnnɛ n'ani nnye nea ɛtɔɔ
# Actual Twi: Yaw nkae nea esii nnera anadwo mpo
#
# English: I'm sorry to have kept you waiting so long.
# Predicted Twi: Ɛyɛ me sɛ me ne wo n'ani n'ani
# Actual Twi: Fa kye me sɛ mama wakyɛre saa.
#
# English: This coat fits you.
# Predicted Twi: - a few inches
# Actual Twi: Ataade yi kɔ wo
#
# English: Yaw is clueless.
# Predicted Twi: Yɛn n'ani n'ani.
# Actual Twi: Yaw nnim hwee
#
# English: He was listening to the music in his room.
# Predicted Twi: Ɔde n'ani n'ani n'ani n'ani
# Actual Twi: Na ɔretie nnwom wɔ ne dan mu hɔ
#
# English: Please tell me where the bus stop is.
# Predicted Twi: Please, sɛ me n'ani abus no no.
# Actual Twi: Mepa wo kyɛw kyerɛ me baabi a wɔfa kai no
#
# English: Here is the book you are looking for.
# Predicted Twi: HERE ne nsɛm no a worehwehwɛ.
# Actual Twi: Nwoma a na worehwehwɛ no nie
#
# English: I didn't want to go, but I needed to.
# Predicted Twi: M'ani nnim sɛ mekɔ, nanso ɛnsɛ
# Actual Twi: Na mempɛ sɛ mɛkɔ, nanso na ɛsɛ sɛ metumi kɔ
#
# English: There is no furniture left in the room.
# Predicted Twi: Ɛnyɛ n'adwuma no mu.
# Actual Twi: Akongua biara nni dan no mu biom...
#
# English: Yaw will be back tomorrow.
# Predicted Twi: Yɛbɛkɔ tomorrow.
# Actual Twi: Yaw bɛba kyena
#
# English: These books are worth reading at least once.
# Predicted Twi: Ɛnyɛ sɛ nsɛm a ɛbɛyɛ
# Actual Twi: Anyɛ yiye koraa no, ɛfata sɛ yɛkenkan nhoma ahorow yi pɛnkoro.
#
# English: I'll go out after having dinner.
# Predicted Twi: M'ani bɛkɔ awie.
# Actual Twi: Midi anwumere aduane wie a, mepue.
#
# English: How long's Yaw been sick?
# Predicted Twi: Ɔkwan a Yaw awie?
# Actual Twi: Mmere sɛn ni na Yaw ayare?
#
# English: Open your book to page 59.
# Predicted Twi: Ɛsɛ sɛ wobɛka sɛ wobɛka sɛ
# Actual Twi: Bue wo nwoma no kɔ kratafa a ɛtɔ so aduonum nkron.
#
# English: I'm sorry I'm late.
# Predicted Twi: M'ani gye sɛ meyɛ akɔ.
# Actual Twi: Fakyɛ me sɛ makyɛre
#
# English: I'd like to know your opinion.
# Predicted Twi: M'ani pɛ sɛ meka wo n'ani.
# Actual Twi: Mepɛ sɛ mihunu w'adwenkyerɛ
#
# English: That's enough for today. I'm tired.
# Predicted Twi: Ɛyɛ sɛ meyɛ n'ani a yɛn n
# Actual Twi: Nea yɛbɛyɛ nnɛ ara no no, mabrɛ
#
# English: Yaw is well known as a singer.
# Predicted Twi: Yɛyɛ a ɔbɛyɛ a ɔbɛyɛ a ɔ
# Actual Twi: Wɔnim Yaw yiye sɛ nnwomtoni
#
# English: What Yaw said is right.
# Predicted Twi: Ɛno yɛ nea Yaw kae no.
# Actual Twi: Nea Yaw kae no yɛ ampa
#
# English: Yaw has perfect teeth.
# Predicted Twi: Yɛ n'ani gye n'ani gye.
# Actual Twi: Yaw se yɛ fɛw
#
# English: My grandchildren attend this school.
# Predicted Twi: Me nnamfo no awie a ɛwɔ sukuu.
# Actual Twi: Me nananom ba sukuu wɔ ha.
#
# English: I always have eggs for breakfast.
# Predicted Twi: M'ani gye eggs a ɛwɔ awie.
# Actual Twi: Midi nkosua anɔpa biara
#
# English: I doubt Yaw is really a doctor.
# Predicted Twi: M'ani gye sɛ Yaw yɛ ɔkyerɛkyer
# Actual Twi: Mennye nni sɛ Yaw yɛ dɔketa
#
# English: I hate my eyebrows.
# Predicted Twi: Me n'ani n'ani n'ani.
# Actual Twi: Mikyi m'ani akyi nwii
#
# English: Yaw recorded it.
# Predicted Twi: Yɛkyerɛw no.
# Actual Twi: Yaw kyerɛwee
#
# English: It's too early to leave.
# Predicted Twi: Ɛyɛ sɛ ɛsɛ sɛ ɔbɛkɔ.
# Actual Twi: Mɛnkɔ mmeretiawa yi mu
#
# English: Yaw earns three times more than me.
# Predicted Twi: Yɛpɛ sɛ me n'ani n'ani n'
# Actual Twi: Yaw akatua yɛ mede mmɔho mmiensa
#
# English: I don't like traveling by air.
# Predicted Twi: M'ani gye sɛ mekɔ a ɛtɔ a
# Actual Twi: Mempɛ wiemhyɛn mu akwantu
#
# English: There was something I needed to get at the supermarket, but I forgot to pick it up.
# Predicted Twi: Ɛyɛɛ biribi a mewɔ ɔdan no mu, nanso me
# Actual Twi: Na ɛsɛ sɛ metɔ ade/biribi wɔ sotɔɔ no mu nanso mewerefiie
#
# English: I wonder why she is so worried.
# Predicted Twi: Ɛno nti sɛ ɔreyɛ sɛ ɔreyɛ
# Actual Twi: Misusuw nea enti a ɔreteetee saa no ho.
#
# English: I am of the opinion that necessity is the mother of invention.
# Predicted Twi: M'ani gye sɛ nsɛm yɛ ɔhaw
# Actual Twi: M'adwenkyerɛ ne sɛ ohia ma adwendwen
#
# English: My bag is too old. I must buy a new one.
# Predicted Twi: Me bag no yɛ ɔhaw.
# Actual Twi: Mebɔtɔ no akyɛre dodo, ɛsɛ sɛ metɔ foforow
#
# English: Who asked you?
# Predicted Twi: Ɔbaa wo?
# Actual Twi: Hwan na obisaa wo?
#
# English: Yaw lay awake almost all night thinking about Adwoa.
# Predicted Twi: Yɛree n'adwuma a ɛtɔ nn
# Actual Twi: Yaw dwenee Adwoa ho anadwo no nyinaa a wanna
#
# English: You're just wasting your time.
# Predicted Twi: W'ani n'ani n'ani n'ani.
# Actual Twi: Woresɛe wommere
